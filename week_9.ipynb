# %% [markdown]
# <a href="https://colab.research.google.com/github/KhrTim/AI-application-systems/blob/main/week_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy as np
import logging

# %%
tf.get_logger().setLevel(logging.ERROR)

# %%
EPOCHS = 500
BATCH_SIZE = 16

# %%
boston_housing = keras.datasets.boston_housing
(raw_x_train, y_train), (raw_x_test, y_test) = boston_housing.load_data()
# Out:
# ...
# 57026/57026 [==============================] - 0s 0us/step

# %%
x_mean = np.mean(raw_x_train, axis=0)
x_stddev = np.std(raw_x_train, axis=0)

# %%
x_train = (raw_x_train - x_mean) / x_stddev

# %%
x_test = (raw_x_test - x_mean) / x_stddev

# %%
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=[13]))
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='linear'))
model.compile(loss="mean_squared_error", optimizer="adam", 
              metrics=["mean_absolute_error"])
model.summary()
history = model.fit(x_train, y_train,
                    validation_data=(x_test, y_test), 
                    epochs=EPOCHS, 
                    batch_size=BATCH_SIZE,
                    verbose=2,
                    shuffle=True)
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_6 (Dense)             (None, 64)                896
#
#  dense_7 (Dense)             (None, 64)                4160
#
#  dense_8 (Dense)             (None, 1)                 65
#
# ...
# Total params: 5,121
# Trainable params: 5,121
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 26/26 - 1s - loss: 540.0783 - mean_absolute_error: 21.2386 - val_loss: 508.3344 - val_mean_absolute_error: 20.5343 - 933ms/epoch - 36ms/step
# Epoch 2/500
# 26/26 - 0s - loss: 412.9367 - mean_absolute_error: 18.0894 - val_loss: 334.3681 - val_mean_absolute_error: 16.0527 - 74ms/epoch - 3ms/step
# Epoch 3/500
# 26/26 - 0s - loss: 213.0641 - mean_absolute_error: 12.0571 - val_loss: 125.8738 - val_mean_absolute_error: 9.2598 - 82ms/epoch - 3ms/step
# Epoch 4/500
# ...
