# %% [markdown]
# <a href="https://colab.research.google.com/github/KhrTim/AI-application-systems/blob/main/Weekly_sessions/week9/Week_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy as np
import logging

# %% [markdown]
# # Read and standartize the data

# %%
tf.get_logger().setLevel(logging.ERROR)

# %%
EPOCHS = 500
BATCH_SIZE = 16

# %%
boston_housing = keras.datasets.boston_housing
(raw_x_train, y_train), (raw_x_test, y_test) = boston_housing.load_data()
# Out:
# ...
# 57026/57026 [==============================] - 0s 0us/step

# %%
x_mean = np.mean(raw_x_train, axis=0)
x_stddev = np.std(raw_x_train, axis=0)

# %%
x_train = (raw_x_train - x_mean) / x_stddev

# %%
x_test = (raw_x_test - x_mean) / x_stddev

# %% [markdown]
# # Create and train model

# %%
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=[13]))
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='linear'))
model.compile(loss="mean_squared_error", optimizer="adam", 
              metrics=["mean_absolute_error"])
model.summary()
history = model.fit(x_train, y_train,
                    validation_data=(x_test, y_test), 
                    epochs=EPOCHS, 
                    batch_size=BATCH_SIZE,
                    verbose=2,
                    shuffle=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 64)                896
#
#  dense_1 (Dense)             (None, 64)                4160
#
#  dense_2 (Dense)             (None, 1)                 65
#
# ...
# Total params: 5,121
# Trainable params: 5,121
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 26/26 - 2s - loss: 533.3470 - mean_absolute_error: 21.1826 - val_loss: 488.7213 - val_mean_absolute_error: 20.1679 - 2s/epoch - 74ms/step
# Epoch 2/500
# 26/26 - 0s - loss: 381.5901 - mean_absolute_error: 17.2752 - val_loss: 293.2435 - val_mean_absolute_error: 14.7481 - 228ms/epoch - 9ms/step
# Epoch 3/500
# 26/26 - 0s - loss: 186.5165 - mean_absolute_error: 10.8729 - val_loss: 126.3451 - val_mean_absolute_error: 9.0107 - 193ms/epoch - 7ms/step
# Epoch 4/500
# ...

# %%
prediction = model.predict(x_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %%
for i in range(4):
  print("Prediction: ", prediction[i, 0],
        ", true_value: ", y_test[i])
# Out:
# Prediction:  6.04861 , true_value:  7.2
# Prediction:  19.704561 , true_value:  18.8
# Prediction:  20.227697 , true_value:  19.0
# Prediction:  33.061592 , true_value:  27.0
