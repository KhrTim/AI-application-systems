# %% [markdown]
# <a href="https://colab.research.google.com/github/KhrTim/AI-application-systems/blob/main/week_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

np.random.seed(3)

index_list = [0,1,2,3]

# training examples
x_train=[np.array([1.0, -1.0, -1.0]),
         np.array([1.0, -1.0, 1.0]),
         np.array([1.0, 1.0, -1.0]),
         np.array([1.0, 1.0, 1.0])]

# Ground truth
y_train=[0.0,1.0,1.0,0.0]

# %%
LEARNING_RATE = 0.1

# %%
def neuron_w(input_count):
  """
    Creating weights for a neuron
  """
  
  weights=np.zeros(input_count+1)
  for i in range(1, (input_count+1)):
    weights[i] = np.random.uniform(-1.0, 1.0)
  return weights

# %%
n_w = [neuron_w(2), neuron_w(2),neuron_w(2)] # weights
n_y = [0,0,0] # output
n_error = [0,0,0] # error term

# %%
def show_learning():
  """
    Print weights of each neuron on a particular step
  """
  print("Current weights")
  for i,w in enumerate(n_w):
    print('neuron ', i, ': w0 =', '%5.2f'%w[0],', w1 =',\
          '%5.2f' % w[1], ', w2 =%5.2f' % w[2])
  print('---------------')

# %%
def forward_pass(x):
  """
    First step of back propagation algorithm
  """
  global n_y
  n_y[0] = np.tanh(np.dot(n_w[0],x))
  n_y[1] = np.tanh(np.dot(n_w[1],x))

  n2_inputs = np.array([1.0, n_y[0], n_y[1]])
  z2=np.dot(n_w[2], n2_inputs)
  n_y[2] = 1.0/(1.0 + np.exp(-z2))

# %%
def backward_pass(y_truth):
  """
    Second step of back propagation algorithm
  """
  global n_error
  error_prime = -(y_truth - n_y[2])
  derivative = n_y[2] * (1.0 - n_y[2])
  n_error[2] = error_prime * derivative
  derivative = 1.0 - n_y[0]**2
  n_error[0] = n_w[2][1] * n_error[2] * derivative
  derivative = 1.0 - n_y[1]**2
  n_error[1] = n_w[2][2] * n_error[2] * derivative

# %%
def adjust_weights(x):
  """
    Process of weights adjusting
  """
  global n_w
  n_w[0] -= (x * LEARNING_RATE * n_error[0])
  n_w[1] -= (x * LEARNING_RATE * n_error[1])
  n2_inputs = np.array([1.0, n_y[0], n_y[1]]) # 1.0 is bias
  n_w[2] -= (n2_inputs * LEARNING_RATE * n_error[2])

# %%
show_learning()
# Out:
# Current weights
# neuron  0 : w0 =  0.00 , w1 =  0.10 , w2 = 0.42
# neuron  1 : w0 =  0.00 , w1 = -0.42 , w2 = 0.02
# neuron  2 : w0 =  0.00 , w1 =  0.79 , w2 = 0.79
# ---------------

# %%
"""
  The training loop
"""

all_correct = False
while not all_correct: # Train until converged
    all_correct = True
    np.random.shuffle(index_list) # Randomize order
    for i in index_list: # Train on all examples
        forward_pass(x_train[i])
        backward_pass(y_train[i])
        adjust_weights(x_train[i])
        show_learning() # Show updated weights
    for i in range(len(x_train)): # Check if converged
        forward_pass(x_train[i])
        print('x1 =', '%4.1f' % x_train[i][1], ', x2 =',
              '%4.1f' % x_train[i][2], ', y =',
              '%.4f' % n_y[2])
        if(((y_train[i] < 0.5) and (n_y[2] >= 0.5))
                or ((y_train[i] >= 0.5) and (n_y[2] < 0.5))):
            all_correct = False
# Out:
# Current weights
# neuron  0 : w0 = -0.01 , w1 =  0.11 , w2 = 0.42
# neuron  1 : w0 = -0.01 , w1 = -0.41 , w2 = 0.03
# neuron  2 : w0 = -0.01 , w1 =  0.79 , w2 = 0.79
# ---------------
# Current weights
# neuron  0 : w0 = -0.00 , w1 =  0.10 , w2 = 0.43
# neuron  1 : w0 = -0.00 , w1 = -0.42 , w2 = 0.03
# neuron  2 : w0 = -0.00 , w1 =  0.79 , w2 = 0.79
# ---------------
# Current weights
# neuron  0 : w0 = -0.01 , w1 =  0.11 , w2 = 0.44
# neuron  1 : w0 = -0.01 , w1 = -0.41 , w2 = 0.04
# neuron  2 : w0 = -0.02 , w1 =  0.80 , w2 = 0.79
# ---------------
# Current weights
# neuron  0 : w0 =  0.00 , w1 =  0.12 , w2 = 0.43
# neuron  1 : w0 = -0.00 , w1 = -0.40 , w2 = 0.03
# neuron  2 : w0 = -0.00 , w1 =  0.79 , w2 = 0.78
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4692
# x1 = -1.0 , x2 =  1.0 , y = 0.6346
# x1 =  1.0 , x2 = -1.0 , y = 0.3646
# x1 =  1.0 , x2 =  1.0 , y = 0.5297
# Current weights
# neuron  0 : w0 =  0.01 , w1 =  0.11 , w2 = 0.43
# neuron  1 : w0 =  0.00 , w1 = -0.40 , w2 = 0.04
# neuron  2 : w0 =  0.01 , w1 =  0.80 , w2 = 0.78
# ---------------
# Current weights
# neuron  0 : w0 =  0.00 , w1 =  0.12 , w2 = 0.44
# neuron  1 : w0 = -0.00 , w1 = -0.40 , w2 = 0.05
# neuron  2 : w0 = -0.01 , w1 =  0.80 , w2 = 0.78
# ---------------
# Current weights
# neuron  0 : w0 = -0.01 , w1 =  0.11 , w2 = 0.43
# neuron  1 : w0 = -0.01 , w1 = -0.41 , w2 = 0.04
# neuron  2 : w0 = -0.02 , w1 =  0.80 , w2 = 0.78
# ---------------
# Current weights
# neuron  0 : w0 =  0.00 , w1 =  0.12 , w2 = 0.42
# neuron  1 : w0 = -0.00 , w1 = -0.40 , w2 = 0.03
# neuron  2 : w0 = -0.00 , w1 =  0.79 , w2 = 0.78
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4694
# x1 = -1.0 , x2 =  1.0 , y = 0.6309
# x1 =  1.0 , x2 = -1.0 , y = 0.3672
# x1 =  1.0 , x2 =  1.0 , y = 0.5284
# Current weights
# neuron  0 : w0 =  0.01 , w1 =  0.13 , w2 = 0.41
# neuron  1 : w0 =  0.01 , w1 = -0.39 , w2 = 0.02
# neuron  2 : w0 =  0.01 , w1 =  0.79 , w2 = 0.77
# ---------------
# Current weights
# neuron  0 : w0 =  0.01 , w1 =  0.13 , w2 = 0.40
# neuron  1 : w0 = -0.00 , w1 = -0.40 , w2 = 0.01
# neuron  2 : w0 = -0.00 , w1 =  0.78 , w2 = 0.78
# ---------------
# Current weights
# neuron  0 : w0 = -0.00 , w1 =  0.13 , w2 = 0.41
# neuron  1 : w0 = -0.01 , w1 = -0.39 , w2 = 0.02
# neuron  2 : w0 = -0.01 , w1 =  0.79 , w2 = 0.77
# ---------------
# Current weights
# neuron  0 : w0 =  0.01 , w1 =  0.13 , w2 = 0.42
# neuron  1 : w0 = -0.01 , w1 = -0.39 , w2 = 0.02
# neuron  2 : w0 = -0.01 , w1 =  0.79 , w2 = 0.78
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4698
# x1 = -1.0 , x2 =  1.0 , y = 0.6278
# x1 =  1.0 , x2 = -1.0 , y = 0.3699
# x1 =  1.0 , x2 =  1.0 , y = 0.5274
# Current weights
# neuron  0 : w0 =  0.02 , w1 =  0.14 , w2 = 0.40
# neuron  1 : w0 =  0.00 , w1 = -0.38 , w2 = 0.01
# neuron  2 : w0 =  0.01 , w1 =  0.78 , w2 = 0.77
# ---------------
# Current weights
# neuron  0 : w0 =  0.01 , w1 =  0.13 , w2 = 0.40
# neuron  1 : w0 = -0.01 , w1 = -0.39 , w2 = 0.00
# neuron  2 : w0 = -0.00 , w1 =  0.78 , w2 = 0.78
# ---------------
# Current weights
# neuron  0 : w0 =  0.00 , w1 =  0.14 , w2 = 0.40
# neuron  1 : w0 = -0.01 , w1 = -0.38 , w2 = 0.01
# neuron  2 : w0 = -0.02 , w1 =  0.78 , w2 = 0.77
# ---------------
# Current weights
# neuron  0 : w0 =  0.01 , w1 =  0.13 , w2 = 0.41
# neuron  1 : w0 = -0.01 , w1 = -0.39 , w2 = 0.02
# neuron  2 : w0 = -0.01 , w1 =  0.79 , w2 = 0.77
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4702
# x1 = -1.0 , x2 =  1.0 , y = 0.6248
# x1 =  1.0 , x2 = -1.0 , y = 0.3727
# x1 =  1.0 , x2 =  1.0 , y = 0.5265
# Current weights
# neuron  0 : w0 =  0.00 , w1 =  0.14 , w2 = 0.42
# neuron  1 : w0 = -0.02 , w1 = -0.38 , w2 = 0.03
# neuron  2 : w0 = -0.02 , w1 =  0.79 , w2 = 0.77
# ---------------
# Current weights
# neuron  0 : w0 =  0.01 , w1 =  0.15 , w2 = 0.41
# neuron  1 : w0 = -0.01 , w1 = -0.37 , w2 = 0.02
# neuron  2 : w0 = -0.00 , w1 =  0.79 , w2 = 0.76
# ---------------
# Current weights
# neuron  0 : w0 =  0.02 , w1 =  0.14 , w2 = 0.41
# neuron  1 : w0 =  0.00 , w1 = -0.38 , w2 = 0.02
# neuron  2 : w0 =  0.01 , w1 =  0.79 , w2 = 0.77
# ---------------
# Current weights
# neuron  0 : w0 =  0.01 , w1 =  0.13 , w2 = 0.41
# neuron  1 : w0 = -0.01 , w1 = -0.39 , w2 = 0.01
# neuron  2 : w0 = -0.01 , w1 =  0.78 , w2 = 0.77
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4707
# x1 = -1.0 , x2 =  1.0 , y = 0.6218
# x1 =  1.0 , x2 = -1.0 , y = 0.3754
# x1 =  1.0 , x2 =  1.0 , y = 0.5256
# Current weights
# neuron  0 : w0 =  0.00 , w1 =  0.13 , w2 = 0.40
# neuron  1 : w0 = -0.02 , w1 = -0.40 , w2 = 0.01
# neuron  2 : w0 = -0.02 , w1 =  0.78 , w2 = 0.78
# ---------------
# Current weights
# neuron  0 : w0 = -0.00 , w1 =  0.13 , w2 = 0.41
# neuron  1 : w0 = -0.03 , w1 = -0.39 , w2 = 0.01
# neuron  2 : w0 = -0.03 , w1 =  0.78 , w2 = 0.77
# ---------------
# Current weights
# neuron  0 : w0 =  0.00 , w1 =  0.13 , w2 = 0.41
# neuron  1 : w0 = -0.02 , w1 = -0.40 , w2 = 0.02
# neuron  2 : w0 = -0.02 , w1 =  0.78 , w2 = 0.78
# ---------------
# Current weights
# neuron  0 : w0 =  0.01 , w1 =  0.14 , w2 = 0.40
# neuron  1 : w0 = -0.01 , w1 = -0.39 , w2 = 0.01
# neuron  2 : w0 = -0.01 , w1 =  0.78 , w2 = 0.77
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4713
# x1 = -1.0 , x2 =  1.0 , y = 0.6192
# x1 =  1.0 , x2 = -1.0 , y = 0.3782
# x1 =  1.0 , x2 =  1.0 , y = 0.5250
# Current weights
# neuron  0 : w0 =  0.02 , w1 =  0.13 , w2 = 0.41
# neuron  1 : w0 = -0.00 , w1 = -0.39 , w2 = 0.02
# neuron  2 : w0 =  0.00 , w1 =  0.78 , w2 = 0.77
# ---------------
# Current weights
# neuron  0 : w0 =  0.01 , w1 =  0.14 , w2 = 0.42
# neuron  1 : w0 = -0.01 , w1 = -0.38 , w2 = 0.02
# neuron  2 : w0 = -0.01 , w1 =  0.79 , w2 = 0.77
# ---------------
# Current weights
# neuron  0 : w0 =  0.02 , w1 =  0.15 , w2 = 0.40
# neuron  1 : w0 = -0.00 , w1 = -0.37 , w2 = 0.01
# neuron  2 : w0 =  0.00 , w1 =  0.78 , w2 = 0.76
# ---------------
# Current weights
# neuron  0 : w0 =  0.02 , w1 =  0.14 , w2 = 0.40
# neuron  1 : w0 = -0.01 , w1 = -0.38 , w2 = 0.01
# neuron  2 : w0 = -0.01 , w1 =  0.78 , w2 = 0.77
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4716
# x1 = -1.0 , x2 =  1.0 , y = 0.6161
# x1 =  1.0 , x2 = -1.0 , y = 0.3810
# x1 =  1.0 , x2 =  1.0 , y = 0.5241
# Current weights
# neuron  0 : w0 =  0.01 , w1 =  0.15 , w2 = 0.40
# neuron  1 : w0 = -0.02 , w1 = -0.38 , w2 = 0.01
# neuron  2 : w0 = -0.02 , w1 =  0.78 , w2 = 0.76
# ---------------
# Current weights
# neuron  0 : w0 =  0.02 , w1 =  0.14 , w2 = 0.41
# neuron  1 : w0 = -0.01 , w1 = -0.38 , w2 = 0.02
# neuron  2 : w0 = -0.01 , w1 =  0.79 , w2 = 0.77
# ---------------
# Current weights
# neuron  0 : w0 =  0.03 , w1 =  0.15 , w2 = 0.40
# neuron  1 : w0 = -0.00 , w1 = -0.37 , w2 = 0.01
# neuron  2 : w0 =  0.00 , w1 =  0.78 , w2 = 0.76
# ---------------
# Current weights
# neuron  0 : w0 =  0.02 , w1 =  0.14 , w2 = 0.39
# neuron  1 : w0 = -0.01 , w1 = -0.38 , w2 = 0.00
# neuron  2 : w0 = -0.01 , w1 =  0.78 , w2 = 0.77
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4722
# x1 = -1.0 , x2 =  1.0 , y = 0.6134
# x1 =  1.0 , x2 = -1.0 , y = 0.3838
# x1 =  1.0 , x2 =  1.0 , y = 0.5234
# Current weights
# neuron  0 : w0 =  0.01 , w1 =  0.14 , w2 = 0.38
# neuron  1 : w0 = -0.02 , w1 = -0.39 , w2 =-0.01
# neuron  2 : w0 = -0.02 , w1 =  0.77 , w2 = 0.77
# ---------------
# Current weights
# neuron  0 : w0 =  0.00 , w1 =  0.14 , w2 = 0.39
# neuron  1 : w0 = -0.03 , w1 = -0.38 , w2 = 0.00
# neuron  2 : w0 = -0.04 , w1 =  0.77 , w2 = 0.77
# ---------------
# Current weights
# neuron  0 : w0 =  0.01 , w1 =  0.14 , w2 = 0.40
# neuron  1 : w0 = -0.02 , w1 = -0.39 , w2 = 0.01
# neuron  2 : w0 = -0.03 , w1 =  0.78 , w2 = 0.77
# ---------------
# Current weights
# neuron  0 : w0 =  0.02 , w1 =  0.15 , w2 = 0.39
# neuron  1 : w0 = -0.01 , w1 = -0.38 , w2 =-0.00
# neuron  2 : w0 = -0.01 , w1 =  0.77 , w2 = 0.76
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4729
# x1 = -1.0 , x2 =  1.0 , y = 0.6111
# x1 =  1.0 , x2 = -1.0 , y = 0.3866
# x1 =  1.0 , x2 =  1.0 , y = 0.5232
# Current weights
# neuron  0 : w0 =  0.01 , w1 =  0.15 , w2 = 0.39
# neuron  1 : w0 = -0.02 , w1 = -0.37 , w2 = 0.01
# neuron  2 : w0 = -0.02 , w1 =  0.78 , w2 = 0.76
# ---------------
# Current weights
# neuron  0 : w0 =  0.01 , w1 =  0.15 , w2 = 0.39
# neuron  1 : w0 = -0.03 , w1 = -0.38 , w2 =-0.00
# neuron  2 : w0 = -0.04 , w1 =  0.77 , w2 = 0.76
# ---------------
# Current weights
# neuron  0 : w0 =  0.02 , w1 =  0.16 , w2 = 0.38
# neuron  1 : w0 = -0.02 , w1 = -0.37 , w2 =-0.01
# neuron  2 : w0 = -0.02 , w1 =  0.77 , w2 = 0.76
# ---------------
# Current weights
# neuron  0 : w0 =  0.02 , w1 =  0.15 , w2 = 0.38
# neuron  1 : w0 = -0.01 , w1 = -0.38 , w2 =-0.01
# neuron  2 : w0 = -0.01 , w1 =  0.77 , w2 = 0.76
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4736
# x1 = -1.0 , x2 =  1.0 , y = 0.6089
# x1 =  1.0 , x2 = -1.0 , y = 0.3895
# x1 =  1.0 , x2 =  1.0 , y = 0.5229
# Current weights
# neuron  0 : w0 =  0.04 , w1 =  0.16 , w2 = 0.37
# neuron  1 : w0 = -0.00 , w1 = -0.37 , w2 =-0.02
# neuron  2 : w0 =  0.00 , w1 =  0.77 , w2 = 0.76
# ---------------
# Current weights
# neuron  0 : w0 =  0.03 , w1 =  0.15 , w2 = 0.37
# neuron  1 : w0 = -0.01 , w1 = -0.38 , w2 =-0.02
# neuron  2 : w0 = -0.01 , w1 =  0.76 , w2 = 0.76
# ---------------
# Current weights
# neuron  0 : w0 =  0.02 , w1 =  0.16 , w2 = 0.37
# neuron  1 : w0 = -0.02 , w1 = -0.37 , w2 =-0.02
# neuron  2 : w0 = -0.02 , w1 =  0.77 , w2 = 0.76
# ---------------
# Current weights
# neuron  0 : w0 =  0.03 , w1 =  0.15 , w2 = 0.38
# neuron  1 : w0 = -0.01 , w1 = -0.37 , w2 =-0.01
# neuron  2 : w0 = -0.01 , w1 =  0.77 , w2 = 0.76
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4742
# x1 = -1.0 , x2 =  1.0 , y = 0.6066
# x1 =  1.0 , x2 = -1.0 , y = 0.3922
# x1 =  1.0 , x2 =  1.0 , y = 0.5227
# Current weights
# neuron  0 : w0 =  0.04 , w1 =  0.17 , w2 = 0.37
# neuron  1 : w0 = -0.00 , w1 = -0.36 , w2 =-0.02
# neuron  2 : w0 =  0.00 , w1 =  0.77 , w2 = 0.75
# ---------------
# Current weights
# neuron  0 : w0 =  0.03 , w1 =  0.16 , w2 = 0.36
# neuron  1 : w0 = -0.01 , w1 = -0.37 , w2 =-0.03
# neuron  2 : w0 = -0.01 , w1 =  0.76 , w2 = 0.76
# ---------------
# Current weights
# neuron  0 : w0 =  0.02 , w1 =  0.17 , w2 = 0.37
# neuron  1 : w0 = -0.02 , w1 = -0.37 , w2 =-0.02
# neuron  2 : w0 = -0.02 , w1 =  0.76 , w2 = 0.76
# ---------------
# Current weights
# neuron  0 : w0 =  0.03 , w1 =  0.16 , w2 = 0.38
# neuron  1 : w0 = -0.01 , w1 = -0.37 , w2 =-0.01
# neuron  2 : w0 = -0.01 , w1 =  0.77 , w2 = 0.76
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4747
# x1 = -1.0 , x2 =  1.0 , y = 0.6045
# x1 =  1.0 , x2 = -1.0 , y = 0.3950
# x1 =  1.0 , x2 =  1.0 , y = 0.5225
# Current weights
# neuron  0 : w0 =  0.04 , w1 =  0.15 , w2 = 0.38
# neuron  1 : w0 = -0.01 , w1 = -0.38 , w2 =-0.01
# neuron  2 : w0 = -0.01 , w1 =  0.77 , w2 = 0.76
# ---------------
# Current weights
# neuron  0 : w0 =  0.03 , w1 =  0.14 , w2 = 0.38
# neuron  1 : w0 = -0.02 , w1 = -0.39 , w2 =-0.02
# neuron  2 : w0 = -0.02 , w1 =  0.76 , w2 = 0.77
# ---------------
# Current weights
# neuron  0 : w0 =  0.02 , w1 =  0.15 , w2 = 0.38
# neuron  1 : w0 = -0.02 , w1 = -0.38 , w2 =-0.01
# neuron  2 : w0 = -0.03 , w1 =  0.77 , w2 = 0.76
# ---------------
# Current weights
# neuron  0 : w0 =  0.03 , w1 =  0.16 , w2 = 0.37
# neuron  1 : w0 = -0.01 , w1 = -0.37 , w2 =-0.02
# neuron  2 : w0 = -0.02 , w1 =  0.76 , w2 = 0.76
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4751
# x1 = -1.0 , x2 =  1.0 , y = 0.6020
# x1 =  1.0 , x2 = -1.0 , y = 0.3978
# x1 =  1.0 , x2 =  1.0 , y = 0.5222
# Current weights
# neuron  0 : w0 =  0.04 , w1 =  0.17 , w2 = 0.36
# neuron  1 : w0 = -0.01 , w1 = -0.36 , w2 =-0.03
# neuron  2 : w0 = -0.00 , w1 =  0.76 , w2 = 0.75
# ---------------
# Current weights
# neuron  0 : w0 =  0.05 , w1 =  0.17 , w2 = 0.37
# neuron  1 : w0 =  0.00 , w1 = -0.37 , w2 =-0.02
# neuron  2 : w0 =  0.01 , w1 =  0.76 , w2 = 0.75
# ---------------
# Current weights
# neuron  0 : w0 =  0.04 , w1 =  0.17 , w2 = 0.38
# neuron  1 : w0 = -0.01 , w1 = -0.36 , w2 =-0.01
# neuron  2 : w0 = -0.00 , w1 =  0.77 , w2 = 0.75
# ---------------
# Current weights
# neuron  0 : w0 =  0.04 , w1 =  0.17 , w2 = 0.37
# neuron  1 : w0 = -0.02 , w1 = -0.37 , w2 =-0.02
# neuron  2 : w0 = -0.02 , w1 =  0.76 , w2 = 0.75
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4754
# x1 = -1.0 , x2 =  1.0 , y = 0.5994
# x1 =  1.0 , x2 = -1.0 , y = 0.4004
# x1 =  1.0 , x2 =  1.0 , y = 0.5218
# Current weights
# neuron  0 : w0 =  0.05 , w1 =  0.18 , w2 = 0.36
# neuron  1 : w0 = -0.01 , w1 = -0.36 , w2 =-0.03
# neuron  2 : w0 = -0.00 , w1 =  0.76 , w2 = 0.75
# ---------------
# Current weights
# neuron  0 : w0 =  0.05 , w1 =  0.17 , w2 = 0.36
# neuron  1 : w0 =  0.00 , w1 = -0.36 , w2 =-0.02
# neuron  2 : w0 =  0.01 , w1 =  0.76 , w2 = 0.75
# ---------------
# Current weights
# neuron  0 : w0 =  0.05 , w1 =  0.18 , w2 = 0.37
# neuron  1 : w0 = -0.01 , w1 = -0.36 , w2 =-0.02
# neuron  2 : w0 = -0.01 , w1 =  0.77 , w2 = 0.75
# ---------------
# Current weights
# neuron  0 : w0 =  0.04 , w1 =  0.17 , w2 = 0.36
# neuron  1 : w0 = -0.02 , w1 = -0.36 , w2 =-0.02
# neuron  2 : w0 = -0.02 , w1 =  0.76 , w2 = 0.75
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4757
# x1 = -1.0 , x2 =  1.0 , y = 0.5970
# x1 =  1.0 , x2 = -1.0 , y = 0.4030
# x1 =  1.0 , x2 =  1.0 , y = 0.5215
# Current weights
# neuron  0 : w0 =  0.03 , w1 =  0.16 , w2 = 0.36
# neuron  1 : w0 = -0.02 , w1 = -0.37 , w2 =-0.03
# neuron  2 : w0 = -0.03 , w1 =  0.75 , w2 = 0.76
# ---------------
# Current weights
# neuron  0 : w0 =  0.03 , w1 =  0.17 , w2 = 0.36
# neuron  1 : w0 = -0.03 , w1 = -0.37 , w2 =-0.03
# neuron  2 : w0 = -0.04 , w1 =  0.76 , w2 = 0.75
# ---------------
# Current weights
# neuron  0 : w0 =  0.03 , w1 =  0.16 , w2 = 0.37
# neuron  1 : w0 = -0.02 , w1 = -0.37 , w2 =-0.02
# neuron  2 : w0 = -0.03 , w1 =  0.76 , w2 = 0.76
# ---------------
# Current weights
# neuron  0 : w0 =  0.04 , w1 =  0.17 , w2 = 0.36
# neuron  1 : w0 = -0.02 , w1 = -0.36 , w2 =-0.03
# neuron  2 : w0 = -0.02 , w1 =  0.76 , w2 = 0.75
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4764
# x1 = -1.0 , x2 =  1.0 , y = 0.5954
# x1 =  1.0 , x2 = -1.0 , y = 0.4059
# x1 =  1.0 , x2 =  1.0 , y = 0.5217
# Current weights
# neuron  0 : w0 =  0.05 , w1 =  0.17 , w2 = 0.37
# neuron  1 : w0 = -0.01 , w1 = -0.37 , w2 =-0.02
# neuron  2 : w0 = -0.01 , w1 =  0.76 , w2 = 0.75
# ---------------
# Current weights
# neuron  0 : w0 =  0.04 , w1 =  0.17 , w2 = 0.38
# neuron  1 : w0 = -0.02 , w1 = -0.36 , w2 =-0.01
# neuron  2 : w0 = -0.02 , w1 =  0.77 , w2 = 0.75
# ---------------
# Current weights
# neuron  0 : w0 =  0.04 , w1 =  0.17 , w2 = 0.37
# neuron  1 : w0 = -0.03 , w1 = -0.37 , w2 =-0.02
# neuron  2 : w0 = -0.03 , w1 =  0.76 , w2 = 0.76
# ---------------
# Current weights
# neuron  0 : w0 =  0.05 , w1 =  0.18 , w2 = 0.36
# neuron  1 : w0 = -0.02 , w1 = -0.36 , w2 =-0.03
# neuron  2 : w0 = -0.02 , w1 =  0.76 , w2 = 0.75
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4769
# x1 = -1.0 , x2 =  1.0 , y = 0.5932
# x1 =  1.0 , x2 = -1.0 , y = 0.4087
# x1 =  1.0 , x2 =  1.0 , y = 0.5216
# Current weights
# neuron  0 : w0 =  0.06 , w1 =  0.19 , w2 = 0.35
# neuron  1 : w0 = -0.01 , w1 = -0.35 , w2 =-0.04
# neuron  2 : w0 = -0.01 , w1 =  0.76 , w2 = 0.75
# ---------------
# Current weights
# neuron  0 : w0 =  0.05 , w1 =  0.19 , w2 = 0.35
# neuron  1 : w0 = -0.01 , w1 = -0.34 , w2 =-0.03
# neuron  2 : w0 = -0.02 , w1 =  0.76 , w2 = 0.74
# ---------------
# Current weights
# neuron  0 : w0 =  0.04 , w1 =  0.19 , w2 = 0.35
# neuron  1 : w0 = -0.02 , w1 = -0.35 , w2 =-0.04
# neuron  2 : w0 = -0.03 , w1 =  0.75 , w2 = 0.75
# ---------------
# Current weights
# neuron  0 : w0 =  0.05 , w1 =  0.18 , w2 = 0.35
# neuron  1 : w0 = -0.02 , w1 = -0.36 , w2 =-0.03
# neuron  2 : w0 = -0.02 , w1 =  0.76 , w2 = 0.75
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4775
# x1 = -1.0 , x2 =  1.0 , y = 0.5915
# x1 =  1.0 , x2 = -1.0 , y = 0.4113
# x1 =  1.0 , x2 =  1.0 , y = 0.5218
# Current weights
# neuron  0 : w0 =  0.06 , w1 =  0.17 , w2 = 0.36
# neuron  1 : w0 = -0.01 , w1 = -0.37 , w2 =-0.03
# neuron  2 : w0 = -0.01 , w1 =  0.76 , w2 = 0.75
# ---------------
# Current weights
# neuron  0 : w0 =  0.07 , w1 =  0.18 , w2 = 0.35
# neuron  1 : w0 =  0.00 , w1 = -0.36 , w2 =-0.04
# neuron  2 : w0 =  0.00 , w1 =  0.76 , w2 = 0.75
# ---------------
# Current weights
# neuron  0 : w0 =  0.06 , w1 =  0.18 , w2 = 0.34
# neuron  1 : w0 = -0.01 , w1 = -0.36 , w2 =-0.05
# neuron  2 : w0 = -0.01 , w1 =  0.75 , w2 = 0.75
# ---------------
# Current weights
# neuron  0 : w0 =  0.05 , w1 =  0.18 , w2 = 0.35
# neuron  1 : w0 = -0.02 , w1 = -0.36 , w2 =-0.04
# neuron  2 : w0 = -0.02 , w1 =  0.75 , w2 = 0.75
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4778
# x1 = -1.0 , x2 =  1.0 , y = 0.5894
# x1 =  1.0 , x2 = -1.0 , y = 0.4139
# x1 =  1.0 , x2 =  1.0 , y = 0.5216
# Current weights
# neuron  0 : w0 =  0.06 , w1 =  0.19 , w2 = 0.34
# neuron  1 : w0 = -0.01 , w1 = -0.35 , w2 =-0.05
# neuron  2 : w0 = -0.01 , w1 =  0.75 , w2 = 0.74
# ---------------
# Current weights
# neuron  0 : w0 =  0.06 , w1 =  0.20 , w2 = 0.35
# neuron  1 : w0 = -0.01 , w1 = -0.34 , w2 =-0.04
# neuron  2 : w0 = -0.02 , w1 =  0.76 , w2 = 0.74
# ---------------
# Current weights
# neuron  0 : w0 =  0.05 , w1 =  0.19 , w2 = 0.34
# neuron  1 : w0 = -0.02 , w1 = -0.35 , w2 =-0.05
# neuron  2 : w0 = -0.03 , w1 =  0.75 , w2 = 0.74
# ---------------
# Current weights
# neuron  0 : w0 =  0.06 , w1 =  0.19 , w2 = 0.35
# neuron  1 : w0 = -0.01 , w1 = -0.35 , w2 =-0.04
# neuron  2 : w0 = -0.02 , w1 =  0.75 , w2 = 0.75
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4784
# x1 = -1.0 , x2 =  1.0 , y = 0.5879
# x1 =  1.0 , x2 = -1.0 , y = 0.4165
# x1 =  1.0 , x2 =  1.0 , y = 0.5218
# Current weights
# neuron  0 : w0 =  0.05 , w1 =  0.18 , w2 = 0.34
# neuron  1 : w0 = -0.02 , w1 = -0.36 , w2 =-0.05
# neuron  2 : w0 = -0.04 , w1 =  0.75 , w2 = 0.75
# ---------------
# Current weights
# neuron  0 : w0 =  0.06 , w1 =  0.17 , w2 = 0.35
# neuron  1 : w0 = -0.02 , w1 = -0.37 , w2 =-0.04
# neuron  2 : w0 = -0.03 , w1 =  0.75 , w2 = 0.75
# ---------------
# Current weights
# neuron  0 : w0 =  0.05 , w1 =  0.18 , w2 = 0.36
# neuron  1 : w0 = -0.02 , w1 = -0.36 , w2 =-0.03
# neuron  2 : w0 = -0.04 , w1 =  0.75 , w2 = 0.75
# ---------------
# Current weights
# neuron  0 : w0 =  0.06 , w1 =  0.19 , w2 = 0.35
# neuron  1 : w0 = -0.01 , w1 = -0.35 , w2 =-0.04
# neuron  2 : w0 = -0.02 , w1 =  0.75 , w2 = 0.74
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4789
# x1 = -1.0 , x2 =  1.0 , y = 0.5863
# x1 =  1.0 , x2 = -1.0 , y = 0.4193
# x1 =  1.0 , x2 =  1.0 , y = 0.5222
# Current weights
# neuron  0 : w0 =  0.05 , w1 =  0.20 , w2 = 0.35
# neuron  1 : w0 = -0.02 , w1 = -0.34 , w2 =-0.04
# neuron  2 : w0 = -0.04 , w1 =  0.76 , w2 = 0.74
# ---------------
# Current weights
# neuron  0 : w0 =  0.06 , w1 =  0.21 , w2 = 0.34
# neuron  1 : w0 = -0.01 , w1 = -0.34 , w2 =-0.05
# neuron  2 : w0 = -0.02 , w1 =  0.75 , w2 = 0.74
# ---------------
# Current weights
# neuron  0 : w0 =  0.07 , w1 =  0.20 , w2 = 0.35
# neuron  1 : w0 = -0.01 , w1 = -0.34 , w2 =-0.04
# neuron  2 : w0 = -0.01 , w1 =  0.76 , w2 = 0.74
# ---------------
# Current weights
# neuron  0 : w0 =  0.06 , w1 =  0.19 , w2 = 0.34
# neuron  1 : w0 = -0.01 , w1 = -0.35 , w2 =-0.05
# neuron  2 : w0 = -0.02 , w1 =  0.75 , w2 = 0.74
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4795
# x1 = -1.0 , x2 =  1.0 , y = 0.5847
# x1 =  1.0 , x2 = -1.0 , y = 0.4219
# x1 =  1.0 , x2 =  1.0 , y = 0.5222
# Current weights
# neuron  0 : w0 =  0.06 , w1 =  0.19 , w2 = 0.34
# neuron  1 : w0 = -0.02 , w1 = -0.36 , w2 =-0.06
# neuron  2 : w0 = -0.04 , w1 =  0.74 , w2 = 0.75
# ---------------
# Current weights
# neuron  0 : w0 =  0.06 , w1 =  0.18 , w2 = 0.34
# neuron  1 : w0 = -0.02 , w1 = -0.37 , w2 =-0.05
# neuron  2 : w0 = -0.03 , w1 =  0.74 , w2 = 0.75
# ---------------
# Current weights
# neuron  0 : w0 =  0.08 , w1 =  0.19 , w2 = 0.33
# neuron  1 : w0 = -0.01 , w1 = -0.36 , w2 =-0.06
# neuron  2 : w0 = -0.01 , w1 =  0.74 , w2 = 0.75
# ---------------
# Current weights
# neuron  0 : w0 =  0.07 , w1 =  0.20 , w2 = 0.34
# neuron  1 : w0 = -0.01 , w1 = -0.35 , w2 =-0.05
# neuron  2 : w0 = -0.02 , w1 =  0.75 , w2 = 0.74
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4799
# x1 = -1.0 , x2 =  1.0 , y = 0.5831
# x1 =  1.0 , x2 = -1.0 , y = 0.4245
# x1 =  1.0 , x2 =  1.0 , y = 0.5226
# Current weights
# neuron  0 : w0 =  0.06 , w1 =  0.19 , w2 = 0.33
# neuron  1 : w0 = -0.02 , w1 = -0.36 , w2 =-0.06
# neuron  2 : w0 = -0.04 , w1 =  0.74 , w2 = 0.75
# ---------------
# Current weights
# neuron  0 : w0 =  0.05 , w1 =  0.20 , w2 = 0.34
# neuron  1 : w0 = -0.03 , w1 = -0.35 , w2 =-0.05
# neuron  2 : w0 = -0.05 , w1 =  0.75 , w2 = 0.74
# ---------------
# Current weights
# neuron  0 : w0 =  0.06 , w1 =  0.19 , w2 = 0.35
# neuron  1 : w0 = -0.02 , w1 = -0.36 , w2 =-0.04
# neuron  2 : w0 = -0.04 , w1 =  0.75 , w2 = 0.74
# ---------------
# Current weights
# neuron  0 : w0 =  0.07 , w1 =  0.20 , w2 = 0.34
# neuron  1 : w0 = -0.01 , w1 = -0.35 , w2 =-0.05
# neuron  2 : w0 = -0.03 , w1 =  0.75 , w2 = 0.74
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4806
# x1 = -1.0 , x2 =  1.0 , y = 0.5819
# x1 =  1.0 , x2 = -1.0 , y = 0.4272
# x1 =  1.0 , x2 =  1.0 , y = 0.5230
# Current weights
# neuron  0 : w0 =  0.06 , w1 =  0.19 , w2 = 0.33
# neuron  1 : w0 = -0.02 , w1 = -0.36 , w2 =-0.06
# neuron  2 : w0 = -0.04 , w1 =  0.74 , w2 = 0.75
# ---------------
# Current weights
# neuron  0 : w0 =  0.07 , w1 =  0.19 , w2 = 0.34
# neuron  1 : w0 = -0.01 , w1 = -0.36 , w2 =-0.05
# neuron  2 : w0 = -0.03 , w1 =  0.74 , w2 = 0.75
# ---------------
# Current weights
# neuron  0 : w0 =  0.08 , w1 =  0.20 , w2 = 0.33
# neuron  1 : w0 = -0.00 , w1 = -0.35 , w2 =-0.06
# neuron  2 : w0 = -0.01 , w1 =  0.74 , w2 = 0.74
# ---------------
# Current weights
# neuron  0 : w0 =  0.08 , w1 =  0.21 , w2 = 0.33
# neuron  1 : w0 = -0.01 , w1 = -0.35 , w2 =-0.06
# neuron  2 : w0 = -0.03 , w1 =  0.75 , w2 = 0.74
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4810
# x1 = -1.0 , x2 =  1.0 , y = 0.5804
# x1 =  1.0 , x2 = -1.0 , y = 0.4298
# x1 =  1.0 , x2 =  1.0 , y = 0.5234
# Current weights
# neuron  0 : w0 =  0.07 , w1 =  0.20 , w2 = 0.33
# neuron  1 : w0 = -0.02 , w1 = -0.35 , w2 =-0.06
# neuron  2 : w0 = -0.04 , w1 =  0.74 , w2 = 0.74
# ---------------
# Current weights
# neuron  0 : w0 =  0.08 , w1 =  0.19 , w2 = 0.34
# neuron  1 : w0 = -0.01 , w1 = -0.36 , w2 =-0.06
# neuron  2 : w0 = -0.03 , w1 =  0.74 , w2 = 0.75
# ---------------
# Current weights
# neuron  0 : w0 =  0.09 , w1 =  0.20 , w2 = 0.32
# neuron  1 : w0 = -0.00 , w1 = -0.35 , w2 =-0.07
# neuron  2 : w0 = -0.01 , w1 =  0.74 , w2 = 0.74
# ---------------
# Current weights
# neuron  0 : w0 =  0.08 , w1 =  0.21 , w2 = 0.33
# neuron  1 : w0 = -0.01 , w1 = -0.34 , w2 =-0.06
# neuron  2 : w0 = -0.03 , w1 =  0.75 , w2 = 0.74
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4813
# x1 = -1.0 , x2 =  1.0 , y = 0.5790
# x1 =  1.0 , x2 = -1.0 , y = 0.4323
# x1 =  1.0 , x2 =  1.0 , y = 0.5238
# Current weights
# neuron  0 : w0 =  0.09 , w1 =  0.22 , w2 = 0.32
# neuron  1 : w0 = -0.00 , w1 = -0.33 , w2 =-0.07
# neuron  2 : w0 = -0.01 , w1 =  0.74 , w2 = 0.73
# ---------------
# Current weights
# neuron  0 : w0 =  0.10 , w1 =  0.21 , w2 = 0.33
# neuron  1 : w0 =  0.01 , w1 = -0.34 , w2 =-0.06
# neuron  2 : w0 = -0.00 , w1 =  0.75 , w2 = 0.74
# ---------------
# Current weights
# neuron  0 : w0 =  0.09 , w1 =  0.22 , w2 = 0.34
# neuron  1 : w0 = -0.00 , w1 = -0.33 , w2 =-0.05
# neuron  2 : w0 = -0.02 , w1 =  0.75 , w2 = 0.73
# ---------------
# Current weights
# neuron  0 : w0 =  0.08 , w1 =  0.21 , w2 = 0.33
# neuron  1 : w0 = -0.01 , w1 = -0.34 , w2 =-0.06
# neuron  2 : w0 = -0.03 , w1 =  0.74 , w2 = 0.74
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4815
# x1 = -1.0 , x2 =  1.0 , y = 0.5773
# x1 =  1.0 , x2 = -1.0 , y = 0.4346
# x1 =  1.0 , x2 =  1.0 , y = 0.5239
# Current weights
# neuron  0 : w0 =  0.07 , w1 =  0.22 , w2 = 0.34
# neuron  1 : w0 = -0.02 , w1 = -0.33 , w2 =-0.05
# neuron  2 : w0 = -0.04 , w1 =  0.75 , w2 = 0.73
# ---------------
# Current weights
# neuron  0 : w0 =  0.08 , w1 =  0.21 , w2 = 0.35
# neuron  1 : w0 = -0.01 , w1 = -0.34 , w2 =-0.05
# neuron  2 : w0 = -0.03 , w1 =  0.75 , w2 = 0.73
# ---------------
# Current weights
# neuron  0 : w0 =  0.09 , w1 =  0.22 , w2 = 0.33
# neuron  1 : w0 = -0.00 , w1 = -0.33 , w2 =-0.06
# neuron  2 : w0 = -0.02 , w1 =  0.75 , w2 = 0.73
# ---------------
# Current weights
# neuron  0 : w0 =  0.09 , w1 =  0.22 , w2 = 0.33
# neuron  1 : w0 = -0.01 , w1 = -0.34 , w2 =-0.06
# neuron  2 : w0 = -0.03 , w1 =  0.74 , w2 = 0.74
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4821
# x1 = -1.0 , x2 =  1.0 , y = 0.5760
# x1 =  1.0 , x2 = -1.0 , y = 0.4371
# x1 =  1.0 , x2 =  1.0 , y = 0.5241
# Current weights
# neuron  0 : w0 =  0.09 , w1 =  0.21 , w2 = 0.34
# neuron  1 : w0 = -0.00 , w1 = -0.35 , w2 =-0.06
# neuron  2 : w0 = -0.02 , w1 =  0.74 , w2 = 0.74
# ---------------
# Current weights
# neuron  0 : w0 =  0.10 , w1 =  0.22 , w2 = 0.33
# neuron  1 : w0 =  0.01 , w1 = -0.34 , w2 =-0.07
# neuron  2 : w0 = -0.01 , w1 =  0.74 , w2 = 0.73
# ---------------
# Current weights
# neuron  0 : w0 =  0.10 , w1 =  0.21 , w2 = 0.32
# neuron  1 : w0 = -0.00 , w1 = -0.35 , w2 =-0.08
# neuron  2 : w0 = -0.02 , w1 =  0.74 , w2 = 0.74
# ---------------
# Current weights
# neuron  0 : w0 =  0.09 , w1 =  0.22 , w2 = 0.33
# neuron  1 : w0 = -0.01 , w1 = -0.34 , w2 =-0.07
# neuron  2 : w0 = -0.03 , w1 =  0.74 , w2 = 0.73
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4823
# x1 = -1.0 , x2 =  1.0 , y = 0.5744
# x1 =  1.0 , x2 = -1.0 , y = 0.4393
# x1 =  1.0 , x2 =  1.0 , y = 0.5242
# Current weights
# neuron  0 : w0 =  0.10 , w1 =  0.21 , w2 = 0.33
# neuron  1 : w0 = -0.00 , w1 = -0.35 , w2 =-0.06
# neuron  2 : w0 = -0.02 , w1 =  0.74 , w2 = 0.74
# ---------------
# Current weights
# neuron  0 : w0 =  0.11 , w1 =  0.22 , w2 = 0.32
# neuron  1 : w0 =  0.01 , w1 = -0.34 , w2 =-0.07
# neuron  2 : w0 = -0.01 , w1 =  0.74 , w2 = 0.73
# ---------------
# Current weights
# neuron  0 : w0 =  0.10 , w1 =  0.23 , w2 = 0.33
# neuron  1 : w0 = -0.00 , w1 = -0.33 , w2 =-0.06
# neuron  2 : w0 = -0.02 , w1 =  0.75 , w2 = 0.73
# ---------------
# Current weights
# neuron  0 : w0 =  0.09 , w1 =  0.22 , w2 = 0.32
# neuron  1 : w0 = -0.01 , w1 = -0.34 , w2 =-0.07
# neuron  2 : w0 = -0.03 , w1 =  0.74 , w2 = 0.73
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4824
# x1 = -1.0 , x2 =  1.0 , y = 0.5729
# x1 =  1.0 , x2 = -1.0 , y = 0.4416
# x1 =  1.0 , x2 =  1.0 , y = 0.5244
# Current weights
# neuron  0 : w0 =  0.09 , w1 =  0.23 , w2 = 0.33
# neuron  1 : w0 = -0.02 , w1 = -0.33 , w2 =-0.06
# neuron  2 : w0 = -0.04 , w1 =  0.75 , w2 = 0.73
# ---------------
# Current weights
# neuron  0 : w0 =  0.10 , w1 =  0.24 , w2 = 0.32
# neuron  1 : w0 = -0.01 , w1 = -0.32 , w2 =-0.07
# neuron  2 : w0 = -0.03 , w1 =  0.75 , w2 = 0.72
# ---------------
# Current weights
# neuron  0 : w0 =  0.10 , w1 =  0.23 , w2 = 0.33
# neuron  1 : w0 = -0.00 , w1 = -0.33 , w2 =-0.07
# neuron  2 : w0 = -0.02 , w1 =  0.75 , w2 = 0.73
# ---------------
# Current weights
# neuron  0 : w0 =  0.10 , w1 =  0.23 , w2 = 0.32
# neuron  1 : w0 = -0.01 , w1 = -0.34 , w2 =-0.07
# neuron  2 : w0 = -0.03 , w1 =  0.74 , w2 = 0.73
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4830
# x1 = -1.0 , x2 =  1.0 , y = 0.5718
# x1 =  1.0 , x2 = -1.0 , y = 0.4439
# x1 =  1.0 , x2 =  1.0 , y = 0.5247
# Current weights
# neuron  0 : w0 =  0.10 , w1 =  0.22 , w2 = 0.33
# neuron  1 : w0 = -0.00 , w1 = -0.34 , w2 =-0.07
# neuron  2 : w0 = -0.02 , w1 =  0.74 , w2 = 0.74
# ---------------
# Current weights
# neuron  0 : w0 =  0.10 , w1 =  0.23 , w2 = 0.34
# neuron  1 : w0 = -0.01 , w1 = -0.34 , w2 =-0.06
# neuron  2 : w0 = -0.03 , w1 =  0.75 , w2 = 0.73
# ---------------
# Current weights
# neuron  0 : w0 =  0.09 , w1 =  0.22 , w2 = 0.33
# neuron  1 : w0 = -0.02 , w1 = -0.34 , w2 =-0.07
# neuron  2 : w0 = -0.05 , w1 =  0.74 , w2 = 0.74
# ---------------
# Current weights
# neuron  0 : w0 =  0.10 , w1 =  0.23 , w2 = 0.32
# neuron  1 : w0 = -0.01 , w1 = -0.33 , w2 =-0.08
# neuron  2 : w0 = -0.03 , w1 =  0.74 , w2 = 0.73
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4833
# x1 = -1.0 , x2 =  1.0 , y = 0.5705
# x1 =  1.0 , x2 = -1.0 , y = 0.4464
# x1 =  1.0 , x2 =  1.0 , y = 0.5251
# Current weights
# neuron  0 : w0 =  0.11 , w1 =  0.24 , w2 = 0.31
# neuron  1 : w0 =  0.00 , w1 = -0.32 , w2 =-0.09
# neuron  2 : w0 = -0.02 , w1 =  0.74 , w2 = 0.73
# ---------------
# Current weights
# neuron  0 : w0 =  0.10 , w1 =  0.23 , w2 = 0.30
# neuron  1 : w0 = -0.01 , w1 = -0.33 , w2 =-0.09
# neuron  2 : w0 = -0.03 , w1 =  0.73 , w2 = 0.73
# ---------------
# Current weights
# neuron  0 : w0 =  0.10 , w1 =  0.24 , w2 = 0.31
# neuron  1 : w0 = -0.01 , w1 = -0.33 , w2 =-0.09
# neuron  2 : w0 = -0.05 , w1 =  0.74 , w2 = 0.73
# ---------------
# Current weights
# neuron  0 : w0 =  0.10 , w1 =  0.23 , w2 = 0.32
# neuron  1 : w0 = -0.01 , w1 = -0.33 , w2 =-0.08
# neuron  2 : w0 = -0.03 , w1 =  0.74 , w2 = 0.73
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4838
# x1 = -1.0 , x2 =  1.0 , y = 0.5697
# x1 =  1.0 , x2 = -1.0 , y = 0.4485
# x1 =  1.0 , x2 =  1.0 , y = 0.5255
# Current weights
# neuron  0 : w0 =  0.10 , w1 =  0.24 , w2 = 0.33
# neuron  1 : w0 = -0.01 , w1 = -0.33 , w2 =-0.07
# neuron  2 : w0 = -0.05 , w1 =  0.74 , w2 = 0.73
# ---------------
# Current weights
# neuron  0 : w0 =  0.10 , w1 =  0.23 , w2 = 0.33
# neuron  1 : w0 = -0.01 , w1 = -0.33 , w2 =-0.06
# neuron  2 : w0 = -0.04 , w1 =  0.75 , w2 = 0.73
# ---------------
# Current weights
# neuron  0 : w0 =  0.10 , w1 =  0.23 , w2 = 0.33
# neuron  1 : w0 = -0.01 , w1 = -0.34 , w2 =-0.07
# neuron  2 : w0 = -0.05 , w1 =  0.74 , w2 = 0.73
# ---------------
# Current weights
# neuron  0 : w0 =  0.11 , w1 =  0.24 , w2 = 0.32
# neuron  1 : w0 = -0.01 , w1 = -0.33 , w2 =-0.08
# neuron  2 : w0 = -0.04 , w1 =  0.74 , w2 = 0.73
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4843
# x1 = -1.0 , x2 =  1.0 , y = 0.5687
# x1 =  1.0 , x2 = -1.0 , y = 0.4509
# x1 =  1.0 , x2 =  1.0 , y = 0.5260
# Current weights
# neuron  0 : w0 =  0.12 , w1 =  0.23 , w2 = 0.32
# neuron  1 : w0 =  0.00 , w1 = -0.34 , w2 =-0.07
# neuron  2 : w0 = -0.03 , w1 =  0.74 , w2 = 0.73
# ---------------
# Current weights
# neuron  0 : w0 =  0.11 , w1 =  0.24 , w2 = 0.33
# neuron  1 : w0 = -0.01 , w1 = -0.33 , w2 =-0.07
# neuron  2 : w0 = -0.04 , w1 =  0.74 , w2 = 0.73
# ---------------
# Current weights
# neuron  0 : w0 =  0.12 , w1 =  0.25 , w2 = 0.32
# neuron  1 : w0 =  0.00 , w1 = -0.32 , w2 =-0.08
# neuron  2 : w0 = -0.02 , w1 =  0.74 , w2 = 0.72
# ---------------
# Current weights
# neuron  0 : w0 =  0.11 , w1 =  0.24 , w2 = 0.32
# neuron  1 : w0 = -0.00 , w1 = -0.33 , w2 =-0.08
# neuron  2 : w0 = -0.04 , w1 =  0.74 , w2 = 0.73
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4846
# x1 = -1.0 , x2 =  1.0 , y = 0.5675
# x1 =  1.0 , x2 = -1.0 , y = 0.4531
# x1 =  1.0 , x2 =  1.0 , y = 0.5262
# Current weights
# neuron  0 : w0 =  0.11 , w1 =  0.25 , w2 = 0.32
# neuron  1 : w0 = -0.01 , w1 = -0.32 , w2 =-0.08
# neuron  2 : w0 = -0.05 , w1 =  0.74 , w2 = 0.72
# ---------------
# Current weights
# neuron  0 : w0 =  0.10 , w1 =  0.24 , w2 = 0.32
# neuron  1 : w0 = -0.02 , w1 = -0.33 , w2 =-0.08
# neuron  2 : w0 = -0.06 , w1 =  0.73 , w2 = 0.73
# ---------------
# Current weights
# neuron  0 : w0 =  0.11 , w1 =  0.25 , w2 = 0.31
# neuron  1 : w0 = -0.01 , w1 = -0.32 , w2 =-0.09
# neuron  2 : w0 = -0.05 , w1 =  0.73 , w2 = 0.73
# ---------------
# Current weights
# neuron  0 : w0 =  0.12 , w1 =  0.24 , w2 = 0.31
# neuron  1 : w0 = -0.00 , w1 = -0.33 , w2 =-0.09
# neuron  2 : w0 = -0.04 , w1 =  0.74 , w2 = 0.73
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4852
# x1 = -1.0 , x2 =  1.0 , y = 0.5669
# x1 =  1.0 , x2 = -1.0 , y = 0.4555
# x1 =  1.0 , x2 =  1.0 , y = 0.5269
# Current weights
# neuron  0 : w0 =  0.13 , w1 =  0.25 , w2 = 0.30
# neuron  1 : w0 =  0.01 , w1 = -0.32 , w2 =-0.10
# neuron  2 : w0 = -0.02 , w1 =  0.74 , w2 = 0.72
# ---------------
# Current weights
# neuron  0 : w0 =  0.12 , w1 =  0.25 , w2 = 0.30
# neuron  1 : w0 = -0.00 , w1 = -0.33 , w2 =-0.10
# neuron  2 : w0 = -0.04 , w1 =  0.73 , w2 = 0.73
# ---------------
# Current weights
# neuron  0 : w0 =  0.13 , w1 =  0.24 , w2 = 0.31
# neuron  1 : w0 =  0.01 , w1 = -0.34 , w2 =-0.10
# neuron  2 : w0 = -0.03 , w1 =  0.73 , w2 = 0.73
# ---------------
# Current weights
# neuron  0 : w0 =  0.12 , w1 =  0.25 , w2 = 0.31
# neuron  1 : w0 = -0.00 , w1 = -0.33 , w2 =-0.09
# neuron  2 : w0 = -0.04 , w1 =  0.74 , w2 = 0.73
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4853
# x1 = -1.0 , x2 =  1.0 , y = 0.5659
# x1 =  1.0 , x2 = -1.0 , y = 0.4574
# x1 =  1.0 , x2 =  1.0 , y = 0.5273
# Current weights
# neuron  0 : w0 =  0.11 , w1 =  0.24 , w2 = 0.31
# neuron  1 : w0 = -0.01 , w1 = -0.34 , w2 =-0.10
# neuron  2 : w0 = -0.05 , w1 =  0.73 , w2 = 0.73
# ---------------
# Current weights
# neuron  0 : w0 =  0.12 , w1 =  0.25 , w2 = 0.30
# neuron  1 : w0 = -0.00 , w1 = -0.33 , w2 =-0.11
# neuron  2 : w0 = -0.04 , w1 =  0.73 , w2 = 0.73
# ---------------
# Current weights
# neuron  0 : w0 =  0.12 , w1 =  0.26 , w2 = 0.30
# neuron  1 : w0 = -0.01 , w1 = -0.32 , w2 =-0.10
# neuron  2 : w0 = -0.05 , w1 =  0.73 , w2 = 0.72
# ---------------
# Current weights
# neuron  0 : w0 =  0.12 , w1 =  0.25 , w2 = 0.31
# neuron  1 : w0 = -0.00 , w1 = -0.33 , w2 =-0.09
# neuron  2 : w0 = -0.04 , w1 =  0.74 , w2 = 0.73
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4857
# x1 = -1.0 , x2 =  1.0 , y = 0.5653
# x1 =  1.0 , x2 = -1.0 , y = 0.4596
# x1 =  1.0 , x2 =  1.0 , y = 0.5279
# Current weights
# neuron  0 : w0 =  0.13 , w1 =  0.24 , w2 = 0.32
# neuron  1 : w0 =  0.01 , w1 = -0.33 , w2 =-0.08
# neuron  2 : w0 = -0.03 , w1 =  0.74 , w2 = 0.73
# ---------------
# Current weights
# neuron  0 : w0 =  0.12 , w1 =  0.25 , w2 = 0.33
# neuron  1 : w0 = -0.00 , w1 = -0.33 , w2 =-0.08
# neuron  2 : w0 = -0.04 , w1 =  0.74 , w2 = 0.72
# ---------------
# Current weights
# neuron  0 : w0 =  0.13 , w1 =  0.26 , w2 = 0.32
# neuron  1 : w0 =  0.01 , w1 = -0.32 , w2 =-0.09
# neuron  2 : w0 = -0.03 , w1 =  0.74 , w2 = 0.72
# ---------------
# Current weights
# neuron  0 : w0 =  0.13 , w1 =  0.26 , w2 = 0.31
# neuron  1 : w0 = -0.00 , w1 = -0.33 , w2 =-0.09
# neuron  2 : w0 = -0.04 , w1 =  0.73 , w2 = 0.73
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4858
# x1 = -1.0 , x2 =  1.0 , y = 0.5642
# x1 =  1.0 , x2 = -1.0 , y = 0.4616
# x1 =  1.0 , x2 =  1.0 , y = 0.5282
# Current weights
# neuron  0 : w0 =  0.12 , w1 =  0.25 , w2 = 0.31
# neuron  1 : w0 = -0.01 , w1 = -0.33 , w2 =-0.10
# neuron  2 : w0 = -0.05 , w1 =  0.73 , w2 = 0.73
# ---------------
# Current weights
# neuron  0 : w0 =  0.13 , w1 =  0.26 , w2 = 0.30
# neuron  1 : w0 =  0.00 , w1 = -0.32 , w2 =-0.11
# neuron  2 : w0 = -0.04 , w1 =  0.73 , w2 = 0.73
# ---------------
# Current weights
# neuron  0 : w0 =  0.14 , w1 =  0.25 , w2 = 0.30
# neuron  1 : w0 =  0.01 , w1 = -0.33 , w2 =-0.10
# neuron  2 : w0 = -0.03 , w1 =  0.73 , w2 = 0.73
# ---------------
# Current weights
# neuron  0 : w0 =  0.13 , w1 =  0.26 , w2 = 0.31
# neuron  1 : w0 =  0.00 , w1 = -0.32 , w2 =-0.10
# neuron  2 : w0 = -0.04 , w1 =  0.73 , w2 = 0.72
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4860
# x1 = -1.0 , x2 =  1.0 , y = 0.5634
# x1 =  1.0 , x2 = -1.0 , y = 0.4636
# x1 =  1.0 , x2 =  1.0 , y = 0.5287
# Current weights
# neuron  0 : w0 =  0.14 , w1 =  0.25 , w2 = 0.32
# neuron  1 : w0 =  0.01 , w1 = -0.33 , w2 =-0.09
# neuron  2 : w0 = -0.03 , w1 =  0.74 , w2 = 0.73
# ---------------
# Current weights
# neuron  0 : w0 =  0.13 , w1 =  0.25 , w2 = 0.31
# neuron  1 : w0 =  0.00 , w1 = -0.34 , w2 =-0.10
# neuron  2 : w0 = -0.04 , w1 =  0.73 , w2 = 0.73
# ---------------
# Current weights
# neuron  0 : w0 =  0.14 , w1 =  0.25 , w2 = 0.30
# neuron  1 : w0 =  0.01 , w1 = -0.33 , w2 =-0.11
# neuron  2 : w0 = -0.03 , w1 =  0.73 , w2 = 0.73
# ---------------
# Current weights
# neuron  0 : w0 =  0.14 , w1 =  0.26 , w2 = 0.31
# neuron  1 : w0 =  0.00 , w1 = -0.32 , w2 =-0.10
# neuron  2 : w0 = -0.04 , w1 =  0.73 , w2 = 0.72
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4860
# x1 = -1.0 , x2 =  1.0 , y = 0.5624
# x1 =  1.0 , x2 = -1.0 , y = 0.4655
# x1 =  1.0 , x2 =  1.0 , y = 0.5291
# Current weights
# neuron  0 : w0 =  0.13 , w1 =  0.27 , w2 = 0.32
# neuron  1 : w0 = -0.01 , w1 = -0.32 , w2 =-0.09
# neuron  2 : w0 = -0.06 , w1 =  0.74 , w2 = 0.72
# ---------------
# Current weights
# neuron  0 : w0 =  0.14 , w1 =  0.28 , w2 = 0.31
# neuron  1 : w0 =  0.00 , w1 = -0.31 , w2 =-0.10
# neuron  2 : w0 = -0.04 , w1 =  0.74 , w2 = 0.72
# ---------------
# Current weights
# neuron  0 : w0 =  0.13 , w1 =  0.27 , w2 = 0.30
# neuron  1 : w0 = -0.00 , w1 = -0.32 , w2 =-0.11
# neuron  2 : w0 = -0.06 , w1 =  0.73 , w2 = 0.72
# ---------------
# Current weights
# neuron  0 : w0 =  0.14 , w1 =  0.27 , w2 = 0.31
# neuron  1 : w0 =  0.00 , w1 = -0.32 , w2 =-0.10
# neuron  2 : w0 = -0.04 , w1 =  0.73 , w2 = 0.72
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4864
# x1 = -1.0 , x2 =  1.0 , y = 0.5619
# x1 =  1.0 , x2 = -1.0 , y = 0.4675
# x1 =  1.0 , x2 =  1.0 , y = 0.5296
# Current weights
# neuron  0 : w0 =  0.15 , w1 =  0.28 , w2 = 0.30
# neuron  1 : w0 =  0.01 , w1 = -0.31 , w2 =-0.11
# neuron  2 : w0 = -0.03 , w1 =  0.73 , w2 = 0.72
# ---------------
# Current weights
# neuron  0 : w0 =  0.14 , w1 =  0.27 , w2 = 0.29
# neuron  1 : w0 =  0.00 , w1 = -0.32 , w2 =-0.12
# neuron  2 : w0 = -0.04 , w1 =  0.73 , w2 = 0.73
# ---------------
# Current weights
# neuron  0 : w0 =  0.14 , w1 =  0.28 , w2 = 0.30
# neuron  1 : w0 = -0.00 , w1 = -0.31 , w2 =-0.11
# neuron  2 : w0 = -0.06 , w1 =  0.73 , w2 = 0.72
# ---------------
# Current weights
# neuron  0 : w0 =  0.14 , w1 =  0.27 , w2 = 0.31
# neuron  1 : w0 =  0.00 , w1 = -0.32 , w2 =-0.10
# neuron  2 : w0 = -0.05 , w1 =  0.73 , w2 = 0.72
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4867
# x1 = -1.0 , x2 =  1.0 , y = 0.5614
# x1 =  1.0 , x2 = -1.0 , y = 0.4693
# x1 =  1.0 , x2 =  1.0 , y = 0.5301
# Current weights
# neuron  0 : w0 =  0.14 , w1 =  0.26 , w2 = 0.30
# neuron  1 : w0 = -0.00 , w1 = -0.33 , w2 =-0.11
# neuron  2 : w0 = -0.06 , w1 =  0.73 , w2 = 0.73
# ---------------
# Current weights
# neuron  0 : w0 =  0.13 , w1 =  0.27 , w2 = 0.31
# neuron  1 : w0 = -0.01 , w1 = -0.32 , w2 =-0.10
# neuron  2 : w0 = -0.07 , w1 =  0.73 , w2 = 0.72
# ---------------
# Current weights
# neuron  0 : w0 =  0.14 , w1 =  0.28 , w2 = 0.30
# neuron  1 : w0 = -0.00 , w1 = -0.31 , w2 =-0.11
# neuron  2 : w0 = -0.06 , w1 =  0.73 , w2 = 0.72
# ---------------
# Current weights
# neuron  0 : w0 =  0.15 , w1 =  0.27 , w2 = 0.31
# neuron  1 : w0 =  0.01 , w1 = -0.32 , w2 =-0.11
# neuron  2 : w0 = -0.05 , w1 =  0.73 , w2 = 0.72
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4871
# x1 = -1.0 , x2 =  1.0 , y = 0.5610
# x1 =  1.0 , x2 = -1.0 , y = 0.4713
# x1 =  1.0 , x2 =  1.0 , y = 0.5307
# Current weights
# neuron  0 : w0 =  0.14 , w1 =  0.28 , w2 = 0.32
# neuron  1 : w0 = -0.00 , w1 = -0.31 , w2 =-0.10
# neuron  2 : w0 = -0.06 , w1 =  0.74 , w2 = 0.72
# ---------------
# Current weights
# neuron  0 : w0 =  0.15 , w1 =  0.29 , w2 = 0.31
# neuron  1 : w0 =  0.01 , w1 = -0.30 , w2 =-0.11
# neuron  2 : w0 = -0.05 , w1 =  0.74 , w2 = 0.71
# ---------------
# Current weights
# neuron  0 : w0 =  0.16 , w1 =  0.28 , w2 = 0.31
# neuron  1 : w0 =  0.02 , w1 = -0.31 , w2 =-0.10
# neuron  2 : w0 = -0.03 , w1 =  0.74 , w2 = 0.72
# ---------------
# Current weights
# neuron  0 : w0 =  0.15 , w1 =  0.28 , w2 = 0.31
# neuron  1 : w0 =  0.01 , w1 = -0.32 , w2 =-0.11
# neuron  2 : w0 = -0.05 , w1 =  0.73 , w2 = 0.72
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4874
# x1 = -1.0 , x2 =  1.0 , y = 0.5604
# x1 =  1.0 , x2 = -1.0 , y = 0.4731
# x1 =  1.0 , x2 =  1.0 , y = 0.5310
# Current weights
# neuron  0 : w0 =  0.16 , w1 =  0.29 , w2 = 0.30
# neuron  1 : w0 =  0.02 , w1 = -0.31 , w2 =-0.12
# neuron  2 : w0 = -0.04 , w1 =  0.73 , w2 = 0.72
# ---------------
# Current weights
# neuron  0 : w0 =  0.17 , w1 =  0.28 , w2 = 0.31
# neuron  1 : w0 =  0.02 , w1 = -0.32 , w2 =-0.11
# neuron  2 : w0 = -0.02 , w1 =  0.74 , w2 = 0.72
# ---------------
# Current weights
# neuron  0 : w0 =  0.16 , w1 =  0.27 , w2 = 0.30
# neuron  1 : w0 =  0.02 , w1 = -0.33 , w2 =-0.12
# neuron  2 : w0 = -0.04 , w1 =  0.73 , w2 = 0.73
# ---------------
# Current weights
# neuron  0 : w0 =  0.16 , w1 =  0.28 , w2 = 0.31
# neuron  1 : w0 =  0.01 , w1 = -0.32 , w2 =-0.11
# neuron  2 : w0 = -0.05 , w1 =  0.73 , w2 = 0.72
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4873
# x1 = -1.0 , x2 =  1.0 , y = 0.5595
# x1 =  1.0 , x2 = -1.0 , y = 0.4747
# x1 =  1.0 , x2 =  1.0 , y = 0.5312
# Current weights
# neuron  0 : w0 =  0.16 , w1 =  0.27 , w2 = 0.32
# neuron  1 : w0 =  0.02 , w1 = -0.33 , w2 =-0.10
# neuron  2 : w0 = -0.04 , w1 =  0.73 , w2 = 0.72
# ---------------
# Current weights
# neuron  0 : w0 =  0.16 , w1 =  0.27 , w2 = 0.31
# neuron  1 : w0 =  0.01 , w1 = -0.34 , w2 =-0.11
# neuron  2 : w0 = -0.05 , w1 =  0.73 , w2 = 0.73
# ---------------
# Current weights
# neuron  0 : w0 =  0.17 , w1 =  0.28 , w2 = 0.30
# neuron  1 : w0 =  0.02 , w1 = -0.33 , w2 =-0.12
# neuron  2 : w0 = -0.04 , w1 =  0.73 , w2 = 0.73
# ---------------
# Current weights
# neuron  0 : w0 =  0.16 , w1 =  0.28 , w2 = 0.31
# neuron  1 : w0 =  0.01 , w1 = -0.32 , w2 =-0.11
# neuron  2 : w0 = -0.05 , w1 =  0.73 , w2 = 0.72
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4872
# x1 = -1.0 , x2 =  1.0 , y = 0.5586
# x1 =  1.0 , x2 = -1.0 , y = 0.4764
# x1 =  1.0 , x2 =  1.0 , y = 0.5316
# Current weights
# neuron  0 : w0 =  0.17 , w1 =  0.28 , w2 = 0.32
# neuron  1 : w0 =  0.02 , w1 = -0.33 , w2 =-0.11
# neuron  2 : w0 = -0.04 , w1 =  0.73 , w2 = 0.72
# ---------------
# Current weights
# neuron  0 : w0 =  0.16 , w1 =  0.27 , w2 = 0.31
# neuron  1 : w0 =  0.01 , w1 = -0.33 , w2 =-0.11
# neuron  2 : w0 = -0.05 , w1 =  0.73 , w2 = 0.73
# ---------------
# Current weights
# neuron  0 : w0 =  0.15 , w1 =  0.28 , w2 = 0.32
# neuron  1 : w0 =  0.00 , w1 = -0.33 , w2 =-0.11
# neuron  2 : w0 = -0.07 , w1 =  0.73 , w2 = 0.72
# ---------------
# Current weights
# neuron  0 : w0 =  0.16 , w1 =  0.29 , w2 = 0.31
# neuron  1 : w0 =  0.01 , w1 = -0.32 , w2 =-0.12
# neuron  2 : w0 = -0.05 , w1 =  0.73 , w2 = 0.72
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4873
# x1 = -1.0 , x2 =  1.0 , y = 0.5579
# x1 =  1.0 , x2 = -1.0 , y = 0.4782
# x1 =  1.0 , x2 =  1.0 , y = 0.5320
# Current weights
# neuron  0 : w0 =  0.16 , w1 =  0.29 , w2 = 0.32
# neuron  1 : w0 =  0.00 , w1 = -0.31 , w2 =-0.11
# neuron  2 : w0 = -0.07 , w1 =  0.74 , w2 = 0.71
# ---------------
# Current weights
# neuron  0 : w0 =  0.16 , w1 =  0.29 , w2 = 0.32
# neuron  1 : w0 =  0.01 , w1 = -0.32 , w2 =-0.10
# neuron  2 : w0 = -0.05 , w1 =  0.74 , w2 = 0.72
# ---------------
# Current weights
# neuron  0 : w0 =  0.16 , w1 =  0.28 , w2 = 0.32
# neuron  1 : w0 =  0.00 , w1 = -0.33 , w2 =-0.11
# neuron  2 : w0 = -0.07 , w1 =  0.73 , w2 = 0.72
# ---------------
# Current weights
# neuron  0 : w0 =  0.17 , w1 =  0.29 , w2 = 0.31
# neuron  1 : w0 =  0.01 , w1 = -0.32 , w2 =-0.12
# neuron  2 : w0 = -0.05 , w1 =  0.73 , w2 = 0.72
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4876
# x1 = -1.0 , x2 =  1.0 , y = 0.5575
# x1 =  1.0 , x2 = -1.0 , y = 0.4801
# x1 =  1.0 , x2 =  1.0 , y = 0.5325
# Current weights
# neuron  0 : w0 =  0.16 , w1 =  0.28 , w2 = 0.30
# neuron  1 : w0 =  0.00 , w1 = -0.33 , w2 =-0.13
# neuron  2 : w0 = -0.07 , w1 =  0.72 , w2 = 0.72
# ---------------
# Current weights
# neuron  0 : w0 =  0.17 , w1 =  0.29 , w2 = 0.29
# neuron  1 : w0 =  0.01 , w1 = -0.32 , w2 =-0.14
# neuron  2 : w0 = -0.05 , w1 =  0.73 , w2 = 0.72
# ---------------
# Current weights
# neuron  0 : w0 =  0.18 , w1 =  0.29 , w2 = 0.30
# neuron  1 : w0 =  0.02 , w1 = -0.32 , w2 =-0.13
# neuron  2 : w0 = -0.04 , w1 =  0.73 , w2 = 0.72
# ---------------
# Current weights
# neuron  0 : w0 =  0.17 , w1 =  0.29 , w2 = 0.31
# neuron  1 : w0 =  0.01 , w1 = -0.32 , w2 =-0.12
# neuron  2 : w0 = -0.06 , w1 =  0.73 , w2 = 0.72
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4875
# x1 = -1.0 , x2 =  1.0 , y = 0.5570
# x1 =  1.0 , x2 = -1.0 , y = 0.4817
# x1 =  1.0 , x2 =  1.0 , y = 0.5330
# Current weights
# neuron  0 : w0 =  0.17 , w1 =  0.29 , w2 = 0.30
# neuron  1 : w0 =  0.01 , w1 = -0.32 , w2 =-0.13
# neuron  2 : w0 = -0.07 , w1 =  0.72 , w2 = 0.72
# ---------------
# Current weights
# neuron  0 : w0 =  0.18 , w1 =  0.30 , w2 = 0.29
# neuron  1 : w0 =  0.01 , w1 = -0.32 , w2 =-0.14
# neuron  2 : w0 = -0.06 , w1 =  0.73 , w2 = 0.72
# ---------------
# Current weights
# neuron  0 : w0 =  0.18 , w1 =  0.29 , w2 = 0.30
# neuron  1 : w0 =  0.02 , w1 = -0.32 , w2 =-0.13
# neuron  2 : w0 = -0.05 , w1 =  0.73 , w2 = 0.72
# ---------------
# Current weights
# neuron  0 : w0 =  0.18 , w1 =  0.30 , w2 = 0.31
# neuron  1 : w0 =  0.02 , w1 = -0.32 , w2 =-0.12
# neuron  2 : w0 = -0.06 , w1 =  0.73 , w2 = 0.72
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4875
# x1 = -1.0 , x2 =  1.0 , y = 0.5565
# x1 =  1.0 , x2 = -1.0 , y = 0.4833
# x1 =  1.0 , x2 =  1.0 , y = 0.5335
# Current weights
# neuron  0 : w0 =  0.18 , w1 =  0.31 , w2 = 0.30
# neuron  1 : w0 =  0.02 , w1 = -0.31 , w2 =-0.13
# neuron  2 : w0 = -0.04 , w1 =  0.73 , w2 = 0.72
# ---------------
# Current weights
# neuron  0 : w0 =  0.19 , w1 =  0.30 , w2 = 0.31
# neuron  1 : w0 =  0.03 , w1 = -0.31 , w2 =-0.12
# neuron  2 : w0 = -0.03 , w1 =  0.74 , w2 = 0.72
# ---------------
# Current weights
# neuron  0 : w0 =  0.19 , w1 =  0.29 , w2 = 0.30
# neuron  1 : w0 =  0.02 , w1 = -0.32 , w2 =-0.13
# neuron  2 : w0 = -0.05 , w1 =  0.73 , w2 = 0.72
# ---------------
# Current weights
# neuron  0 : w0 =  0.18 , w1 =  0.30 , w2 = 0.31
# neuron  1 : w0 =  0.02 , w1 = -0.32 , w2 =-0.12
# neuron  2 : w0 = -0.06 , w1 =  0.73 , w2 = 0.72
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4873
# x1 = -1.0 , x2 =  1.0 , y = 0.5558
# x1 =  1.0 , x2 = -1.0 , y = 0.4847
# x1 =  1.0 , x2 =  1.0 , y = 0.5337
# Current weights
# neuron  0 : w0 =  0.17 , w1 =  0.31 , w2 = 0.32
# neuron  1 : w0 =  0.01 , w1 = -0.31 , w2 =-0.12
# neuron  2 : w0 = -0.07 , w1 =  0.74 , w2 = 0.71
# ---------------
# Current weights
# neuron  0 : w0 =  0.18 , w1 =  0.32 , w2 = 0.31
# neuron  1 : w0 =  0.02 , w1 = -0.30 , w2 =-0.13
# neuron  2 : w0 = -0.06 , w1 =  0.74 , w2 = 0.71
# ---------------
# Current weights
# neuron  0 : w0 =  0.18 , w1 =  0.31 , w2 = 0.30
# neuron  1 : w0 =  0.01 , w1 = -0.31 , w2 =-0.13
# neuron  2 : w0 = -0.07 , w1 =  0.73 , w2 = 0.72
# ---------------
# Current weights
# neuron  0 : w0 =  0.18 , w1 =  0.30 , w2 = 0.31
# neuron  1 : w0 =  0.02 , w1 = -0.32 , w2 =-0.13
# neuron  2 : w0 = -0.06 , w1 =  0.73 , w2 = 0.72
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4875
# x1 = -1.0 , x2 =  1.0 , y = 0.5556
# x1 =  1.0 , x2 = -1.0 , y = 0.4863
# x1 =  1.0 , x2 =  1.0 , y = 0.5342
# Current weights
# neuron  0 : w0 =  0.18 , w1 =  0.31 , w2 = 0.32
# neuron  1 : w0 =  0.01 , w1 = -0.31 , w2 =-0.12
# neuron  2 : w0 = -0.07 , w1 =  0.74 , w2 = 0.71
# ---------------
# Current weights
# neuron  0 : w0 =  0.17 , w1 =  0.31 , w2 = 0.31
# neuron  1 : w0 =  0.00 , w1 = -0.32 , w2 =-0.13
# neuron  2 : w0 = -0.09 , w1 =  0.73 , w2 = 0.72
# ---------------
# Current weights
# neuron  0 : w0 =  0.18 , w1 =  0.31 , w2 = 0.30
# neuron  1 : w0 =  0.01 , w1 = -0.31 , w2 =-0.14
# neuron  2 : w0 = -0.07 , w1 =  0.73 , w2 = 0.71
# ---------------
# Current weights
# neuron  0 : w0 =  0.19 , w1 =  0.31 , w2 = 0.31
# neuron  1 : w0 =  0.02 , w1 = -0.32 , w2 =-0.13
# neuron  2 : w0 = -0.06 , w1 =  0.73 , w2 = 0.72
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4878
# x1 = -1.0 , x2 =  1.0 , y = 0.5556
# x1 =  1.0 , x2 = -1.0 , y = 0.4880
# x1 =  1.0 , x2 =  1.0 , y = 0.5348
# Current weights
# neuron  0 : w0 =  0.18 , w1 =  0.30 , w2 = 0.31
# neuron  1 : w0 =  0.01 , w1 = -0.32 , w2 =-0.14
# neuron  2 : w0 = -0.08 , w1 =  0.72 , w2 = 0.72
# ---------------
# Current weights
# neuron  0 : w0 =  0.19 , w1 =  0.31 , w2 = 0.30
# neuron  1 : w0 =  0.02 , w1 = -0.31 , w2 =-0.15
# neuron  2 : w0 = -0.06 , w1 =  0.73 , w2 = 0.72
# ---------------
# Current weights
# neuron  0 : w0 =  0.18 , w1 =  0.32 , w2 = 0.31
# neuron  1 : w0 =  0.01 , w1 = -0.31 , w2 =-0.14
# neuron  2 : w0 = -0.07 , w1 =  0.73 , w2 = 0.71
# ---------------
# Current weights
# neuron  0 : w0 =  0.19 , w1 =  0.31 , w2 = 0.31
# neuron  1 : w0 =  0.02 , w1 = -0.31 , w2 =-0.13
# neuron  2 : w0 = -0.06 , w1 =  0.73 , w2 = 0.72
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4879
# x1 = -1.0 , x2 =  1.0 , y = 0.5554
# x1 =  1.0 , x2 = -1.0 , y = 0.4895
# x1 =  1.0 , x2 =  1.0 , y = 0.5354
# Current weights
# neuron  0 : w0 =  0.20 , w1 =  0.32 , w2 = 0.30
# neuron  1 : w0 =  0.03 , w1 = -0.31 , w2 =-0.14
# neuron  2 : w0 = -0.05 , w1 =  0.73 , w2 = 0.71
# ---------------
# Current weights
# neuron  0 : w0 =  0.19 , w1 =  0.33 , w2 = 0.31
# neuron  1 : w0 =  0.02 , w1 = -0.30 , w2 =-0.13
# neuron  2 : w0 = -0.06 , w1 =  0.74 , w2 = 0.71
# ---------------
# Current weights
# neuron  0 : w0 =  0.20 , w1 =  0.32 , w2 = 0.32
# neuron  1 : w0 =  0.03 , w1 = -0.31 , w2 =-0.13
# neuron  2 : w0 = -0.05 , w1 =  0.74 , w2 = 0.71
# ---------------
# Current weights
# neuron  0 : w0 =  0.20 , w1 =  0.31 , w2 = 0.31
# neuron  1 : w0 =  0.02 , w1 = -0.31 , w2 =-0.13
# neuron  2 : w0 = -0.07 , w1 =  0.73 , w2 = 0.72
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4878
# x1 = -1.0 , x2 =  1.0 , y = 0.5551
# x1 =  1.0 , x2 = -1.0 , y = 0.4908
# x1 =  1.0 , x2 =  1.0 , y = 0.5356
# Current weights
# neuron  0 : w0 =  0.21 , w1 =  0.32 , w2 = 0.31
# neuron  1 : w0 =  0.03 , w1 = -0.31 , w2 =-0.14
# neuron  2 : w0 = -0.05 , w1 =  0.73 , w2 = 0.71
# ---------------
# Current weights
# neuron  0 : w0 =  0.21 , w1 =  0.31 , w2 = 0.31
# neuron  1 : w0 =  0.04 , w1 = -0.31 , w2 =-0.13
# neuron  2 : w0 = -0.04 , w1 =  0.74 , w2 = 0.72
# ---------------
# Current weights
# neuron  0 : w0 =  0.21 , w1 =  0.32 , w2 = 0.32
# neuron  1 : w0 =  0.03 , w1 = -0.31 , w2 =-0.13
# neuron  2 : w0 = -0.05 , w1 =  0.74 , w2 = 0.71
# ---------------
# Current weights
# neuron  0 : w0 =  0.20 , w1 =  0.32 , w2 = 0.32
# neuron  1 : w0 =  0.02 , w1 = -0.31 , w2 =-0.14
# neuron  2 : w0 = -0.07 , w1 =  0.73 , w2 = 0.72
# ---------------
# ...
# neuron  1 : w0 =  0.30 , w1 = -0.50 , w2 =-0.46
# neuron  2 : w0 = -0.38 , w1 =  0.98 , w2 = 0.82
# ---------------
# Current weights
# neuron  0 : w0 =  0.68 , w1 =  0.74 , w2 = 0.73
# neuron  1 : w0 =  0.30 , w1 = -0.50 , w2 =-0.46
# neuron  2 : w0 = -0.37 , w1 =  0.98 , w2 = 0.82
# ---------------
# Current weights
# neuron  0 : w0 =  0.68 , w1 =  0.74 , w2 = 0.72
# neuron  1 : w0 =  0.31 , w1 = -0.50 , w2 =-0.46
# neuron  2 : w0 = -0.36 , w1 =  0.99 , w2 = 0.83
# ---------------
# Current weights
# neuron  0 : w0 =  0.68 , w1 =  0.74 , w2 = 0.72
# neuron  1 : w0 =  0.30 , w1 = -0.50 , w2 =-0.47
# neuron  2 : w0 = -0.37 , w1 =  0.97 , w2 = 0.83
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4280
# x1 = -1.0 , x2 =  1.0 , y = 0.6142
# x1 =  1.0 , x2 = -1.0 , y = 0.6085
# x1 =  1.0 , x2 =  1.0 , y = 0.5220
# Current weights
# neuron  0 : w0 =  0.69 , w1 =  0.75 , w2 = 0.71
# neuron  1 : w0 =  0.31 , w1 = -0.50 , w2 =-0.48
# neuron  2 : w0 = -0.36 , w1 =  0.98 , w2 = 0.84
# ---------------
# Current weights
# neuron  0 : w0 =  0.68 , w1 =  0.75 , w2 = 0.72
# neuron  1 : w0 =  0.31 , w1 = -0.50 , w2 =-0.48
# neuron  2 : w0 = -0.37 , w1 =  0.99 , w2 = 0.83
# ---------------
# Current weights
# neuron  0 : w0 =  0.69 , w1 =  0.75 , w2 = 0.73
# neuron  1 : w0 =  0.31 , w1 = -0.50 , w2 =-0.47
# neuron  2 : w0 = -0.36 , w1 =  0.99 , w2 = 0.83
# ---------------
# Current weights
# neuron  0 : w0 =  0.69 , w1 =  0.75 , w2 = 0.72
# neuron  1 : w0 =  0.31 , w1 = -0.51 , w2 =-0.48
# neuron  2 : w0 = -0.38 , w1 =  0.98 , w2 = 0.84
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4268
# x1 = -1.0 , x2 =  1.0 , y = 0.6155
# x1 =  1.0 , x2 = -1.0 , y = 0.6098
# x1 =  1.0 , x2 =  1.0 , y = 0.5207
# Current weights
# neuron  0 : w0 =  0.68 , w1 =  0.75 , w2 = 0.73
# neuron  1 : w0 =  0.30 , w1 = -0.51 , w2 =-0.47
# neuron  2 : w0 = -0.39 , w1 =  0.99 , w2 = 0.83
# ---------------
# Current weights
# neuron  0 : w0 =  0.69 , w1 =  0.76 , w2 = 0.72
# neuron  1 : w0 =  0.31 , w1 = -0.50 , w2 =-0.48
# neuron  2 : w0 = -0.38 , w1 =  0.99 , w2 = 0.83
# ---------------
# Current weights
# neuron  0 : w0 =  0.70 , w1 =  0.75 , w2 = 0.73
# neuron  1 : w0 =  0.32 , w1 = -0.51 , w2 =-0.47
# neuron  2 : w0 = -0.37 , w1 =  1.00 , w2 = 0.83
# ---------------
# Current weights
# neuron  0 : w0 =  0.69 , w1 =  0.75 , w2 = 0.73
# neuron  1 : w0 =  0.31 , w1 = -0.51 , w2 =-0.48
# neuron  2 : w0 = -0.38 , w1 =  0.98 , w2 = 0.84
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4257
# x1 = -1.0 , x2 =  1.0 , y = 0.6169
# x1 =  1.0 , x2 = -1.0 , y = 0.6112
# x1 =  1.0 , x2 =  1.0 , y = 0.5195
# Current weights
# neuron  0 : w0 =  0.70 , w1 =  0.76 , w2 = 0.72
# neuron  1 : w0 =  0.32 , w1 = -0.51 , w2 =-0.49
# neuron  2 : w0 = -0.37 , w1 =  0.99 , w2 = 0.84
# ---------------
# Current weights
# neuron  0 : w0 =  0.69 , w1 =  0.76 , w2 = 0.73
# neuron  1 : w0 =  0.32 , w1 = -0.50 , w2 =-0.49
# neuron  2 : w0 = -0.38 , w1 =  1.00 , w2 = 0.84
# ---------------
# Current weights
# neuron  0 : w0 =  0.69 , w1 =  0.76 , w2 = 0.73
# neuron  1 : w0 =  0.31 , w1 = -0.51 , w2 =-0.49
# neuron  2 : w0 = -0.39 , w1 =  0.98 , w2 = 0.84
# ---------------
# Current weights
# neuron  0 : w0 =  0.70 , w1 =  0.76 , w2 = 0.74
# neuron  1 : w0 =  0.32 , w1 = -0.52 , w2 =-0.49
# neuron  2 : w0 = -0.39 , w1 =  0.99 , w2 = 0.85
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4245
# x1 = -1.0 , x2 =  1.0 , y = 0.6185
# x1 =  1.0 , x2 = -1.0 , y = 0.6127
# x1 =  1.0 , x2 =  1.0 , y = 0.5184
# Current weights
# neuron  0 : w0 =  0.71 , w1 =  0.75 , w2 = 0.74
# neuron  1 : w0 =  0.32 , w1 = -0.53 , w2 =-0.48
# neuron  2 : w0 = -0.38 , w1 =  0.99 , w2 = 0.85
# ---------------
# Current weights
# neuron  0 : w0 =  0.70 , w1 =  0.76 , w2 = 0.75
# neuron  1 : w0 =  0.32 , w1 = -0.52 , w2 =-0.48
# neuron  2 : w0 = -0.39 , w1 =  1.00 , w2 = 0.84
# ---------------
# Current weights
# neuron  0 : w0 =  0.71 , w1 =  0.76 , w2 = 0.74
# neuron  1 : w0 =  0.33 , w1 = -0.52 , w2 =-0.48
# neuron  2 : w0 = -0.38 , w1 =  1.01 , w2 = 0.84
# ---------------
# Current weights
# neuron  0 : w0 =  0.70 , w1 =  0.76 , w2 = 0.74
# neuron  1 : w0 =  0.32 , w1 = -0.52 , w2 =-0.49
# neuron  2 : w0 = -0.39 , w1 =  0.99 , w2 = 0.85
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4233
# x1 = -1.0 , x2 =  1.0 , y = 0.6196
# x1 =  1.0 , x2 = -1.0 , y = 0.6142
# x1 =  1.0 , x2 =  1.0 , y = 0.5171
# Current weights
# neuron  0 : w0 =  0.71 , w1 =  0.77 , w2 = 0.74
# neuron  1 : w0 =  0.33 , w1 = -0.52 , w2 =-0.50
# neuron  2 : w0 = -0.38 , w1 =  1.00 , w2 = 0.85
# ---------------
# Current weights
# neuron  0 : w0 =  0.72 , w1 =  0.76 , w2 = 0.74
# neuron  1 : w0 =  0.33 , w1 = -0.52 , w2 =-0.49
# neuron  2 : w0 = -0.37 , w1 =  1.00 , w2 = 0.86
# ---------------
# Current weights
# neuron  0 : w0 =  0.71 , w1 =  0.77 , w2 = 0.75
# neuron  1 : w0 =  0.33 , w1 = -0.52 , w2 =-0.49
# neuron  2 : w0 = -0.38 , w1 =  1.01 , w2 = 0.85
# ---------------
# Current weights
# neuron  0 : w0 =  0.71 , w1 =  0.77 , w2 = 0.75
# neuron  1 : w0 =  0.33 , w1 = -0.53 , w2 =-0.50
# neuron  2 : w0 = -0.40 , w1 =  1.00 , w2 = 0.85
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4219
# x1 = -1.0 , x2 =  1.0 , y = 0.6208
# x1 =  1.0 , x2 = -1.0 , y = 0.6155
# x1 =  1.0 , x2 =  1.0 , y = 0.5157
# Current weights
# neuron  0 : w0 =  0.72 , w1 =  0.76 , w2 = 0.75
# neuron  1 : w0 =  0.33 , w1 = -0.54 , w2 =-0.49
# neuron  2 : w0 = -0.39 , w1 =  1.00 , w2 = 0.86
# ---------------
# Current weights
# neuron  0 : w0 =  0.71 , w1 =  0.76 , w2 = 0.75
# neuron  1 : w0 =  0.33 , w1 = -0.54 , w2 =-0.50
# neuron  2 : w0 = -0.40 , w1 =  0.99 , w2 = 0.87
# ---------------
# Current weights
# neuron  0 : w0 =  0.71 , w1 =  0.77 , w2 = 0.76
# neuron  1 : w0 =  0.32 , w1 = -0.54 , w2 =-0.50
# neuron  2 : w0 = -0.41 , w1 =  1.00 , w2 = 0.86
# ---------------
# Current weights
# neuron  0 : w0 =  0.71 , w1 =  0.77 , w2 = 0.75
# neuron  1 : w0 =  0.33 , w1 = -0.53 , w2 =-0.50
# neuron  2 : w0 = -0.40 , w1 =  1.00 , w2 = 0.86
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4207
# x1 = -1.0 , x2 =  1.0 , y = 0.6221
# x1 =  1.0 , x2 = -1.0 , y = 0.6173
# x1 =  1.0 , x2 =  1.0 , y = 0.5146
# Current weights
# neuron  0 : w0 =  0.72 , w1 =  0.78 , w2 = 0.75
# neuron  1 : w0 =  0.34 , w1 = -0.53 , w2 =-0.51
# neuron  2 : w0 = -0.39 , w1 =  1.01 , w2 = 0.86
# ---------------
# Current weights
# neuron  0 : w0 =  0.73 , w1 =  0.77 , w2 = 0.75
# neuron  1 : w0 =  0.34 , w1 = -0.53 , w2 =-0.50
# neuron  2 : w0 = -0.38 , w1 =  1.02 , w2 = 0.86
# ---------------
# Current weights
# neuron  0 : w0 =  0.72 , w1 =  0.78 , w2 = 0.76
# neuron  1 : w0 =  0.34 , w1 = -0.53 , w2 =-0.50
# neuron  2 : w0 = -0.39 , w1 =  1.02 , w2 = 0.86
# ---------------
# Current weights
# neuron  0 : w0 =  0.72 , w1 =  0.78 , w2 = 0.76
# neuron  1 : w0 =  0.34 , w1 = -0.54 , w2 =-0.51
# neuron  2 : w0 = -0.41 , w1 =  1.01 , w2 = 0.86
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4193
# x1 = -1.0 , x2 =  1.0 , y = 0.6233
# x1 =  1.0 , x2 = -1.0 , y = 0.6186
# x1 =  1.0 , x2 =  1.0 , y = 0.5132
# Current weights
# neuron  0 : w0 =  0.72 , w1 =  0.78 , w2 = 0.76
# neuron  1 : w0 =  0.33 , w1 = -0.54 , w2 =-0.52
# neuron  2 : w0 = -0.42 , w1 =  1.00 , w2 = 0.87
# ---------------
# Current weights
# neuron  0 : w0 =  0.71 , w1 =  0.78 , w2 = 0.76
# neuron  1 : w0 =  0.33 , w1 = -0.54 , w2 =-0.51
# neuron  2 : w0 = -0.43 , w1 =  1.00 , w2 = 0.86
# ---------------
# Current weights
# neuron  0 : w0 =  0.72 , w1 =  0.78 , w2 = 0.77
# neuron  1 : w0 =  0.33 , w1 = -0.55 , w2 =-0.51
# neuron  2 : w0 = -0.42 , w1 =  1.01 , w2 = 0.86
# ---------------
# Current weights
# neuron  0 : w0 =  0.73 , w1 =  0.78 , w2 = 0.76
# neuron  1 : w0 =  0.34 , w1 = -0.54 , w2 =-0.51
# neuron  2 : w0 = -0.41 , w1 =  1.01 , w2 = 0.87
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4183
# x1 = -1.0 , x2 =  1.0 , y = 0.6251
# x1 =  1.0 , x2 = -1.0 , y = 0.6206
# x1 =  1.0 , x2 =  1.0 , y = 0.5123
# Current weights
# neuron  0 : w0 =  0.73 , w1 =  0.79 , w2 = 0.76
# neuron  1 : w0 =  0.35 , w1 = -0.53 , w2 =-0.52
# neuron  2 : w0 = -0.40 , w1 =  1.02 , w2 = 0.87
# ---------------
# Current weights
# neuron  0 : w0 =  0.74 , w1 =  0.78 , w2 = 0.76
# neuron  1 : w0 =  0.35 , w1 = -0.54 , w2 =-0.51
# neuron  2 : w0 = -0.39 , w1 =  1.03 , w2 = 0.87
# ---------------
# Current weights
# neuron  0 : w0 =  0.74 , w1 =  0.78 , w2 = 0.76
# neuron  1 : w0 =  0.35 , w1 = -0.55 , w2 =-0.52
# neuron  2 : w0 = -0.41 , w1 =  1.01 , w2 = 0.88
# ---------------
# Current weights
# neuron  0 : w0 =  0.73 , w1 =  0.79 , w2 = 0.77
# neuron  1 : w0 =  0.35 , w1 = -0.55 , w2 =-0.52
# neuron  2 : w0 = -0.42 , w1 =  1.02 , w2 = 0.87
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4170
# x1 = -1.0 , x2 =  1.0 , y = 0.6263
# x1 =  1.0 , x2 = -1.0 , y = 0.6219
# x1 =  1.0 , x2 =  1.0 , y = 0.5108
# Current weights
# neuron  0 : w0 =  0.74 , w1 =  0.78 , w2 = 0.77
# neuron  1 : w0 =  0.35 , w1 = -0.55 , w2 =-0.51
# neuron  2 : w0 = -0.41 , w1 =  1.03 , w2 = 0.88
# ---------------
# Current weights
# neuron  0 : w0 =  0.74 , w1 =  0.79 , w2 = 0.77
# neuron  1 : w0 =  0.36 , w1 = -0.55 , w2 =-0.52
# neuron  2 : w0 = -0.40 , w1 =  1.03 , w2 = 0.88
# ---------------
# Current weights
# neuron  0 : w0 =  0.73 , w1 =  0.79 , w2 = 0.77
# neuron  1 : w0 =  0.36 , w1 = -0.54 , w2 =-0.52
# neuron  2 : w0 = -0.41 , w1 =  1.04 , w2 = 0.87
# ---------------
# Current weights
# neuron  0 : w0 =  0.73 , w1 =  0.79 , w2 = 0.77
# neuron  1 : w0 =  0.35 , w1 = -0.55 , w2 =-0.52
# neuron  2 : w0 = -0.42 , w1 =  1.03 , w2 = 0.88
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4156
# x1 = -1.0 , x2 =  1.0 , y = 0.6276
# x1 =  1.0 , x2 = -1.0 , y = 0.6233
# x1 =  1.0 , x2 =  1.0 , y = 0.5093
# Current weights
# neuron  0 : w0 =  0.73 , w1 =  0.80 , w2 = 0.78
# neuron  1 : w0 =  0.35 , w1 = -0.55 , w2 =-0.52
# neuron  2 : w0 = -0.43 , w1 =  1.03 , w2 = 0.87
# ---------------
# Current weights
# neuron  0 : w0 =  0.73 , w1 =  0.80 , w2 = 0.78
# neuron  1 : w0 =  0.34 , w1 = -0.56 , w2 =-0.53
# neuron  2 : w0 = -0.45 , w1 =  1.02 , w2 = 0.88
# ---------------
# Current weights
# neuron  0 : w0 =  0.73 , w1 =  0.79 , w2 = 0.78
# neuron  1 : w0 =  0.35 , w1 = -0.56 , w2 =-0.52
# neuron  2 : w0 = -0.44 , w1 =  1.03 , w2 = 0.88
# ---------------
# Current weights
# neuron  0 : w0 =  0.74 , w1 =  0.80 , w2 = 0.78
# neuron  1 : w0 =  0.36 , w1 = -0.56 , w2 =-0.53
# neuron  2 : w0 = -0.43 , w1 =  1.03 , w2 = 0.88
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4146
# x1 = -1.0 , x2 =  1.0 , y = 0.6293
# x1 =  1.0 , x2 = -1.0 , y = 0.6253
# x1 =  1.0 , x2 =  1.0 , y = 0.5083
# Current weights
# neuron  0 : w0 =  0.74 , w1 =  0.80 , w2 = 0.78
# neuron  1 : w0 =  0.35 , w1 = -0.56 , w2 =-0.54
# neuron  2 : w0 = -0.44 , w1 =  1.02 , w2 = 0.89
# ---------------
# Current weights
# neuron  0 : w0 =  0.74 , w1 =  0.79 , w2 = 0.78
# neuron  1 : w0 =  0.36 , w1 = -0.57 , w2 =-0.53
# neuron  2 : w0 = -0.43 , w1 =  1.02 , w2 = 0.89
# ---------------
# Current weights
# neuron  0 : w0 =  0.74 , w1 =  0.80 , w2 = 0.79
# neuron  1 : w0 =  0.35 , w1 = -0.57 , w2 =-0.53
# neuron  2 : w0 = -0.44 , w1 =  1.03 , w2 = 0.88
# ---------------
# Current weights
# neuron  0 : w0 =  0.74 , w1 =  0.80 , w2 = 0.78
# neuron  1 : w0 =  0.36 , w1 = -0.56 , w2 =-0.54
# neuron  2 : w0 = -0.43 , w1 =  1.04 , w2 = 0.89
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4134
# x1 = -1.0 , x2 =  1.0 , y = 0.6310
# x1 =  1.0 , x2 = -1.0 , y = 0.6272
# x1 =  1.0 , x2 =  1.0 , y = 0.5072
# Current weights
# neuron  0 : w0 =  0.74 , w1 =  0.80 , w2 = 0.78
# neuron  1 : w0 =  0.35 , w1 = -0.57 , w2 =-0.54
# neuron  2 : w0 = -0.45 , w1 =  1.02 , w2 = 0.89
# ---------------
# Current weights
# neuron  0 : w0 =  0.75 , w1 =  0.80 , w2 = 0.79
# neuron  1 : w0 =  0.36 , w1 = -0.57 , w2 =-0.54
# neuron  2 : w0 = -0.44 , w1 =  1.03 , w2 = 0.90
# ---------------
# Current weights
# neuron  0 : w0 =  0.74 , w1 =  0.80 , w2 = 0.79
# neuron  1 : w0 =  0.36 , w1 = -0.57 , w2 =-0.53
# neuron  2 : w0 = -0.45 , w1 =  1.04 , w2 = 0.89
# ---------------
# Current weights
# neuron  0 : w0 =  0.75 , w1 =  0.81 , w2 = 0.79
# neuron  1 : w0 =  0.37 , w1 = -0.57 , w2 =-0.54
# neuron  2 : w0 = -0.44 , w1 =  1.04 , w2 = 0.89
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4122
# x1 = -1.0 , x2 =  1.0 , y = 0.6326
# x1 =  1.0 , x2 = -1.0 , y = 0.6291
# x1 =  1.0 , x2 =  1.0 , y = 0.5061
# Current weights
# neuron  0 : w0 =  0.74 , w1 =  0.81 , w2 = 0.79
# neuron  1 : w0 =  0.36 , w1 = -0.56 , w2 =-0.54
# neuron  2 : w0 = -0.45 , w1 =  1.05 , w2 = 0.88
# ---------------
# Current weights
# neuron  0 : w0 =  0.75 , w1 =  0.82 , w2 = 0.79
# neuron  1 : w0 =  0.37 , w1 = -0.56 , w2 =-0.55
# neuron  2 : w0 = -0.44 , w1 =  1.05 , w2 = 0.88
# ---------------
# Current weights
# neuron  0 : w0 =  0.76 , w1 =  0.81 , w2 = 0.79
# neuron  1 : w0 =  0.38 , w1 = -0.56 , w2 =-0.54
# neuron  2 : w0 = -0.43 , w1 =  1.06 , w2 = 0.89
# ---------------
# Current weights
# neuron  0 : w0 =  0.75 , w1 =  0.81 , w2 = 0.79
# neuron  1 : w0 =  0.37 , w1 = -0.57 , w2 =-0.55
# neuron  2 : w0 = -0.44 , w1 =  1.05 , w2 = 0.90
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4111
# x1 = -1.0 , x2 =  1.0 , y = 0.6341
# x1 =  1.0 , x2 = -1.0 , y = 0.6306
# x1 =  1.0 , x2 =  1.0 , y = 0.5046
# Current weights
# neuron  0 : w0 =  0.76 , w1 =  0.82 , w2 = 0.79
# neuron  1 : w0 =  0.38 , w1 = -0.56 , w2 =-0.55
# neuron  2 : w0 = -0.43 , w1 =  1.05 , w2 = 0.90
# ---------------
# Current weights
# neuron  0 : w0 =  0.76 , w1 =  0.82 , w2 = 0.79
# neuron  1 : w0 =  0.37 , w1 = -0.57 , w2 =-0.56
# neuron  2 : w0 = -0.45 , w1 =  1.04 , w2 = 0.91
# ---------------
# Current weights
# neuron  0 : w0 =  0.77 , w1 =  0.81 , w2 = 0.79
# neuron  1 : w0 =  0.38 , w1 = -0.58 , w2 =-0.55
# neuron  2 : w0 = -0.44 , w1 =  1.05 , w2 = 0.91
# ---------------
# Current weights
# neuron  0 : w0 =  0.76 , w1 =  0.82 , w2 = 0.80
# neuron  1 : w0 =  0.38 , w1 = -0.58 , w2 =-0.55
# neuron  2 : w0 = -0.45 , w1 =  1.05 , w2 = 0.90
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4097
# x1 = -1.0 , x2 =  1.0 , y = 0.6356
# x1 =  1.0 , x2 = -1.0 , y = 0.6321
# x1 =  1.0 , x2 =  1.0 , y = 0.5031
# Current weights
# neuron  0 : w0 =  0.76 , w1 =  0.82 , w2 = 0.80
# neuron  1 : w0 =  0.37 , w1 = -0.58 , w2 =-0.56
# neuron  2 : w0 = -0.46 , w1 =  1.04 , w2 = 0.91
# ---------------
# Current weights
# neuron  0 : w0 =  0.76 , w1 =  0.81 , w2 = 0.80
# neuron  1 : w0 =  0.38 , w1 = -0.59 , w2 =-0.55
# neuron  2 : w0 = -0.45 , w1 =  1.05 , w2 = 0.91
# ---------------
# Current weights
# neuron  0 : w0 =  0.76 , w1 =  0.82 , w2 = 0.81
# neuron  1 : w0 =  0.37 , w1 = -0.59 , w2 =-0.55
# neuron  2 : w0 = -0.46 , w1 =  1.05 , w2 = 0.90
# ---------------
# Current weights
# neuron  0 : w0 =  0.76 , w1 =  0.82 , w2 = 0.80
# neuron  1 : w0 =  0.38 , w1 = -0.58 , w2 =-0.56
# neuron  2 : w0 = -0.45 , w1 =  1.06 , w2 = 0.91
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4086
# x1 = -1.0 , x2 =  1.0 , y = 0.6373
# x1 =  1.0 , x2 = -1.0 , y = 0.6340
# x1 =  1.0 , x2 =  1.0 , y = 0.5019
# Current weights
# neuron  0 : w0 =  0.77 , w1 =  0.83 , w2 = 0.80
# neuron  1 : w0 =  0.39 , w1 = -0.57 , w2 =-0.56
# neuron  2 : w0 = -0.45 , w1 =  1.06 , w2 = 0.91
# ---------------
# Current weights
# neuron  0 : w0 =  0.77 , w1 =  0.82 , w2 = 0.80
# neuron  1 : w0 =  0.40 , w1 = -0.58 , w2 =-0.56
# neuron  2 : w0 = -0.44 , w1 =  1.07 , w2 = 0.91
# ---------------
# Current weights
# neuron  0 : w0 =  0.77 , w1 =  0.83 , w2 = 0.81
# neuron  1 : w0 =  0.39 , w1 = -0.58 , w2 =-0.56
# neuron  2 : w0 = -0.45 , w1 =  1.08 , w2 = 0.90
# ---------------
# Current weights
# neuron  0 : w0 =  0.77 , w1 =  0.83 , w2 = 0.81
# neuron  1 : w0 =  0.39 , w1 = -0.59 , w2 =-0.56
# neuron  2 : w0 = -0.46 , w1 =  1.06 , w2 = 0.91
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4071
# x1 = -1.0 , x2 =  1.0 , y = 0.6386
# x1 =  1.0 , x2 = -1.0 , y = 0.6353
# x1 =  1.0 , x2 =  1.0 , y = 0.5003
# Current weights
# neuron  0 : w0 =  0.77 , w1 =  0.83 , w2 = 0.81
# neuron  1 : w0 =  0.38 , w1 = -0.59 , w2 =-0.57
# neuron  2 : w0 = -0.47 , w1 =  1.05 , w2 = 0.92
# ---------------
# Current weights
# neuron  0 : w0 =  0.77 , w1 =  0.83 , w2 = 0.80
# neuron  1 : w0 =  0.39 , w1 = -0.59 , w2 =-0.58
# neuron  2 : w0 = -0.46 , w1 =  1.06 , w2 = 0.92
# ---------------
# Current weights
# neuron  0 : w0 =  0.77 , w1 =  0.84 , w2 = 0.81
# neuron  1 : w0 =  0.39 , w1 = -0.58 , w2 =-0.58
# neuron  2 : w0 = -0.47 , w1 =  1.06 , w2 = 0.91
# ---------------
# Current weights
# neuron  0 : w0 =  0.77 , w1 =  0.83 , w2 = 0.82
# neuron  1 : w0 =  0.39 , w1 = -0.59 , w2 =-0.57
# neuron  2 : w0 = -0.47 , w1 =  1.07 , w2 = 0.92
# ---------------
# x1 = -1.0 , x2 = -1.0 , y = 0.4060
# x1 = -1.0 , x2 =  1.0 , y = 0.6403
# x1 =  1.0 , x2 = -1.0 , y = 0.6371
# x1 =  1.0 , x2 =  1.0 , y = 0.4990
